# %% [markdown]
# # **Creating Automated Vendor Report Creation**

# %% [markdown]
# ## **importing packages**

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('Lead Report - 27th June.csv')
data.head()
# Out:
#                             Prospect ID  Lead Number  Source Referrer  \
# 0  6cf3ad64-1e69-45f7-9cd9-0b1207149ded      5797500              NaN
# 1  51822e7e-b4a4-45ae-a000-3e043de211e6      5798125              NaN
# 2  cc2b16d6-a198-44da-9b09-414dc491d80a      5739923              NaN
# 3  f50a98d3-3a34-4fc3-ba45-b6ae72b60410      5798144              NaN
# 4  e4fa7d46-a5ab-4540-bd8b-f42689f8f66f      5783013              NaN
#
#   Last Notable Activity Last Notable Activity Date         Last Visit Date  \
# 0              Modified     2024-06-27 10:33:39 AM  2024-06-27 10:32:56 AM
# 1              Modified     2024-06-27 10:33:29 AM  2024-06-27 10:33:02 AM
# 2              Modified     2024-06-27 10:33:27 AM  2024-06-27 10:33:26 AM
# 3              Modified     2024-06-27 10:33:11 AM  2024-06-27 10:32:36 AM
# 4              Modified     2024-06-27 10:33:07 AM  2024-06-27 10:32:27 AM
#
#    Related Landing Page Id  First Landing Page Submission Id  \
# 0                      NaN                               NaN
# 1                      NaN                               NaN
# 2                      NaN                               NaN
# 3                      NaN                               NaN
# 4                      NaN                               NaN
#
#    First Landing Page Submission Date                 Last Activity  ...  \
# 0                                 NaN  Outbound Phone Call Activity  ...
# 1                                 NaN  Outbound Phone Call Activity  ...
# 2                                 NaN              Call Disposition  ...
# 3                                 NaN  Outbound Phone Call Activity  ...
# 4                                 NaN  Outbound Phone Call Activity  ...
#
#   Referral Read Post Payment WhatsApp Sub Sub Disposition  Callback SMS Sent  \
# 0                                 NaN                 NaN                NaN
# 1                                 NaN                 NaN                NaN
# 2                                 NaN                 NaN                NaN
# 3                                 NaN                 NaN                NaN
# 4                                 NaN                 NaN                NaN
#
#    FnO Rejection Delivery FnO Rejection Read  Non FnO Rejection Delivery   \
# 0                     NaN                NaN                          NaN
# 1                     NaN                NaN                          NaN
# 2                     NaN                NaN                          NaN
# 3                     NaN                NaN                          NaN
# 4                     NaN                NaN                          NaN
#
#    Non FnO Rejection Read  Callback SMS Sent Date  Rejection WA Sent  \
# 0                     NaN                     NaN                NaN
# 1                     NaN                     NaN                NaN
# 2                     NaN                     NaN                NaN
# 3                     NaN                     NaN                NaN
# 4                     NaN                     NaN                NaN
#
#               Lead Name
# 0             [No Name]
# 1             [No Name]
# 2  RUKMINI KRISHNA RAUT
# 3             [No Name]
# 4        SARABJIT SINGH
#
# [5 rows x 270 columns]

# %%
data.columns.to_list()
# Out:
# ['Prospect ID',
#  'Lead Number',
#  'Source Referrer',
#  'Last Notable Activity',
#  'Last Notable Activity Date',
#  'Last Visit Date',
#  'Related Landing Page Id',
#  'First Landing Page Submission Id',
#  'First Landing Page Submission Date',
#  'Last Activity',
#  'Last Activity Date',
#  'First Activity Date',
#  'Web Referrer',
#  'Web Referrer Keyword',
#  'Recently Modified On',
#  'Conversion Referrer URL',
#  'Source Referrer URL',
#  'Source IP Address',
#  'Latitude',
#  'Longitude',
#  'First Name',
#  'Last Name',
#  'Email',
#  'Phone Number',
#  'Company',
#  'Website',
#  'Do Not Email',
#  'Do Not Track',
#  'Do Not SMS',
#  'Do Not Call',
#  'Lead Source',
#  'Mobile Number',
#  'Payout Source Campaign',
#  'Payout Source Medium',
#  'Source Content',
#  'Notes',
#  'Lead Score',
#  'Engagement Score',
#  'Order Value',
#  'Lead Stage',
#  'QualityScore01',
#  'Created By',
#  'Created On',
#  'Prospect Creation Date',
#  'Modified By',
#  'Modified On',
#  'Time Zone',
#  'TotalVisits',
#  'Page Views Per Visit',
#  'Average Time Per Visit',
#  'Address 1',
#  'Address 2',
#  'City',
#  'State',
#  'Country',
#  'Zip',
#  'Owner',
#  'Owner Email',
#  'Lead Origin',
#  'Mailing Preferences',
#  'Twitter',
#  'Photo Url',
#  'Facebook',
#  'LinkedIn',
#  'Skype Name',
#  'Gtalk User',
#  'Google Plus',
#  'Current Opt In Status',
#  'Opt In Date',
#  'Opt In Details',
#  'Last Opt In Email Sent Date',
#  'Lead Age',
#  'Qualification Status',
#  'Reasons For Not Qualified',
#  'Sub Disposition',
#  'Interested Product',
#  'Prospect Source',
#  'LS Disposition',
#  'Comments',
#  'Client Code',
#  'Final Prospect Source',
#  'Followup Date',
#  'Referee Email',
#  'Referee Mobile',
#  'Utm Adgroup',
#  'Referee Code',
#  'Referee Name',
#  'Utm Device',
#  'Aappsflyer id',
#  'GCLID',
#  'Utm Creative',
#  'App id',
#  'Page URL',
#  'Ekyc stage',
#  'transition e9_Digilocker',
#  'transition e4_Payment',
#  'transition e2_Email',
#  'transition e7_Bank',
#  'transition e3_PAN',
#  'transition e1_Mobile',
#  'transition e6_Onscreen_Sign',
#  'transition e11_PAN Upload',
#  'transition e8_Personal Details',
#  'transition e5_Selfie',
#  'transition e10_Manual_Process',
#  'transition e13_Referral',
#  'transition e12_eSign',
#  'transition e14_Activation_Process',
#  'Pan Number',
#  'Date of Birth',
#  'eKYC Stage Code',
#  'Drip Trigger',
#  'Rejection Reason',
#  'Primary Source',
#  'Primary Source Medium',
#  'Primary Source Campaign',
#  'transition e15_Activated',
#  'Lead Attribution',
#  'Primary Source Date',
#  'Latest Enquiry Date',
#  'Do Not WhatsApp',
#  'Data Type',
#  'No of Connects',
#  'No of Attempts',
#  'Lead Assignment Date',
#  'Disposition Change Date',
#  'First Attempt',
#  'First Connect',
#  'Disposition',
#  'Last Attempt',
#  'Last Connect',
#  '2nd Attempt Date Time',
#  '2nd Connect Date Time',
#  '3rd Attempt Date Time',
#  '3rd Connect Date Time',
#  '4th Attempt Date Time',
#  '4th Connect Date Time',
#  '5th Attempt Date Time',
#  '5th Connect Date Time',
#  'No Of Callback Set',
#  'Lead Priority',
#  'Connectivity Status',
#  'Call Back Date Time',
#  'Pushed to Drishti',
#  'Converted By - User',
#  'Conversion Age',
#  'Customer ID Ameyo',
#  'Drishti Push Date',
#  'Push Date',
#  '1st Attempt Call Duration',
#  '2nd Attempt Call Duration ',
#  '3rd Attempt Call Duration',
#  '4th Attempt Call Duration',
#  '5th Attempt Call Duration',
#  '1st Connect Call Duration ',
#  '2nd Connect Call Duration',
#  '3rd Connect Call Duration ',
#  '4th Connect Call Duration ',
#  '5th Connect Call Duration ',
#  'Dropoff Stage',
#  'Deleted',
#  'Flag',
#  'NewCustomFlag',
#  'Outsourced Team',
#  'UTM Term',
#  'WhatsApp Dropoff Flag',
#  'WhatsApp 3 min',
#  'WhatsApp 5 min',
#  'WhatsApp 7 min',
#  'WhatsApp 20 min',
#  'WhatsApp 1 hr',
#  'WhatsApp 23 hr',
#  'WhatsApp Callback Date Time',
#  'Campaign Name',
#  'Dropoff Link 1',
#  'Dropoff Link 1 Timestamp',
#  'Dropoff Link 2 Timestamp',
#  'Dropoff Link 3 Timestamp',
#  'Dropoff Link 4 Timestamp',
#  'Dropoff Link 5 Timestamp',
#  'Dropoff Link 6 Timestamp',
#  'Dropoff Link 2',
#  'Dropoff Link 3',
#  'Dropoff Link 4',
#  'Dropoff Link 5',
#  'Dropoff Link 6',
#  'WhatsApp 1 Delivered',
#  'WhatsApp 1 Read',
#  'WhatsApp 2 Delivered',
#  'WhatsApp 2 Read',
#  'WhatsApp 3 Delivered',
#  'WhatsApp 3 Read',
#  'WhatsApp 4 Delivered',
#  'WhatsApp 4 Read',
#  'WhatsApp 5 Delivered',
#  'WhatsApp 5 Read',
#  'WhatsApp 6 Delivered',
#  'WhatsApp 6 Read',
#  'WhatsApp 1 CTA Click',
#  'WhatsApp 2 CTA Click',
#  'WhatsApp 3 CTA Click',
#  'WhatsApp 4 CTA Click',
#  'WhatsApp 5 CTA Click',
#  'WhatsApp 6 CTA Click',
#  'Last Source',
#  'Last Source Medium',
#  'Last Source Campaign',
#  'Referral link',
#  'Unsubscribe flag',
#  'Eligible for WhatsApp',
#  'Eligible for WhatsApp On',
#  'Eligible for Appsflyer Sync',
#  'WhatsApp 7 CTA Click',
#  'WhatsApp 8 CTA Click',
#  'WhatsApp 9 CTA Click',
#  'WhatsApp 10 CTA Click',
#  'WhatsApp 3 Day',
#  'WhatsApp 7 Delivered',
#  'WhatsApp 8 Delivered',
#  'WhatsApp 9 Delivered',
#  'WhatsApp 10 Delivered',
#  'WhatsApp 7 Read',
#  'WhatsApp 8 Read',
#  'WhatsApp 9 Read',
#  'WhatsApp 10 Read',
#  'WhatsApp 5 Day',
#  'WhatsApp 7 Day',
#  'WhatsApp 9 Day',
#  'Total Payment Amount',
#  'Pushed to TeleAccess',
#  'Brokerage account type',
#  'AMC plan',
#  '1st Push Date',
#  'WhatsApp Language',
#  'Selfie Read Post Payment WhatsApp',
#  'Selfie Delivery Post Payment WhatsApp',
#  'Esign Read Post Payment WhatsApp',
#  'Esign Delivery Post Payment WhatsApp',
#  'FnO Read Post Payment WhatsApp',
#  'FnO Delivery Post Payment WhatsApp',
#  'PAN Read Post Payment WhatsApp',
#  'PAN Delivery Post Payment WhatsApp',
#  'Post Payment WhatsApp',
#  '1st Connect Owner - User',
#  'Kserve Team',
#  'DIY',
#  'AT Prospect Source',
#  'AT Source',
#  'AT Source Medium',
#  'AT Source Campaign',
#  'Partner Code',
#  'Referral Agent',
#  'Callback Communication Type',
#  'Callback Communication Date',
#  'Eligible for Auto Callback',
#  'Rejection Date Time',
#  '2nd Dropoff',
#  'Digi Read Post Payment WhatsApp',
#  'Digi Delivery Post Payment WhatsApp',
#  'Referral Delivery Post Payment WhatsApp',
#  'Referral Read Post Payment WhatsApp',
#  'Sub Sub Disposition',
#  'Callback SMS Sent',
#  'FnO Rejection Delivery',
#  'FnO Rejection Read',
#  'Non FnO Rejection Delivery ',
#  'Non FnO Rejection Read',
#  'Callback SMS Sent Date',
#  'Rejection WA Sent',
#  'Lead Name']

# %% [markdown]
# ## **extracting required columns**

# %%
data_main = data[['Prospect ID', 'Mobile Number','Phone Number', 'Email', 'Primary Source Campaign', 'eKYC Stage Code', 'Total Payment Amount', 'Created On']]
data_main.head()
# Out:
#                             Prospect ID  Mobile Number    Phone Number  \
# 0  6cf3ad64-1e69-45f7-9cd9-0b1207149ded   9.798394e+09   91 9798394005
# 1  51822e7e-b4a4-45ae-a000-3e043de211e6   7.374997e+09   91 7374996851
# 2  cc2b16d6-a198-44da-9b09-414dc491d80a   9.086708e+09   91 9086707739
# 3  f50a98d3-3a34-4fc3-ba45-b6ae72b60410   6.395005e+09   91 6395005269
# 4  e4fa7d46-a5ab-4540-bd8b-f42689f8f66f   9.988777e+09   91 9988777117
#
#                      Email                        Primary Source Campaign  \
# 0                      NaN                Bazar_Ke_Pandit_YT1_6_June_2024
# 1                      NaN                Bazar_Ke_Pandit_YT1_6_June_2024
# 2  morero7329@nolanzip.com            Diversify_knowledge_YT1_23_May_2024
# 3                      NaN                Bazar_Ke_Pandit_YT1_6_June_2024
# 4     sarabjil77@gmail.com  Trading_With_Karol_YT1_11_May_2024_{click_id}
#
#   eKYC Stage Code  Total Payment Amount              Created On
# 0       e1_Mobile                   NaN  2024-06-26 09:05:25 PM
# 1       e1_Mobile                   NaN  2024-06-26 10:39:21 PM
# 2   e15_Activated                   0.0  2024-06-22 05:07:06 PM
# 3       e1_Mobile                   NaN  2024-06-26 10:42:20 PM
# 4      e4_Payment                   NaN  2024-06-25 07:09:18 PM

# %%
data_main.columns.to_list()
# Out:
# ['Prospect ID',
#  'Mobile Number',
#  'Phone Number',
#  'Email',
#  'Primary Source Campaign',
#  'eKYC Stage Code',
#  'Total Payment Amount',
#  'Created On']

# %% [markdown]
# ## **Task 1 -Fill Mob No from Phone Number where Mob No is empty**

# %%
data_main.isnull().sum()
# Out:
# Prospect ID                   0
# Mobile Number                18
# Phone Number                  0
# Email                      6973
# Primary Source Campaign       0
# eKYC Stage Code              12
# Total Payment Amount       8212
# Created On                    0
# dtype: int64

# %%
# Function to extract the last 10 digits of the phone number
def extract_last_10_digits(phone):
    return str(phone)[-10:]

# %%
# Fill the null values in 'Mobile Number' with the last 10 digits of 'Phone Number'
data_main['Mobile Number'] = data_main.apply(
    lambda row: extract_last_10_digits(row['Phone Number']) if pd.isnull(row['Mobile Number']) or row['Mobile Number'] in ['None', 'nan'] else row['Mobile Number'],
    axis=1)

# Convert 'Mobile Number' to integer to remove any .0, then back to string
data_main['Mobile Number'] = data_main['Mobile Number'].apply(lambda x: str(int(float(x))))

# %%
data_main.head()
# Out:
#                             Prospect ID Mobile Number    Phone Number  \
# 0  6cf3ad64-1e69-45f7-9cd9-0b1207149ded    9798394005   91 9798394005
# 1  51822e7e-b4a4-45ae-a000-3e043de211e6    7374996851   91 7374996851
# 2  cc2b16d6-a198-44da-9b09-414dc491d80a    9086707739   91 9086707739
# 3  f50a98d3-3a34-4fc3-ba45-b6ae72b60410    6395005269   91 6395005269
# 4  e4fa7d46-a5ab-4540-bd8b-f42689f8f66f    9988777117   91 9988777117
#
#                      Email                        Primary Source Campaign  \
# 0                      NaN                Bazar_Ke_Pandit_YT1_6_June_2024
# 1                      NaN                Bazar_Ke_Pandit_YT1_6_June_2024
# 2  morero7329@nolanzip.com            Diversify_knowledge_YT1_23_May_2024
# 3                      NaN                Bazar_Ke_Pandit_YT1_6_June_2024
# 4     sarabjil77@gmail.com  Trading_With_Karol_YT1_11_May_2024_{click_id}
#
#   eKYC Stage Code  Total Payment Amount              Created On
# 0       e1_Mobile                   NaN  2024-06-26 09:05:25 PM
# 1       e1_Mobile                   NaN  2024-06-26 10:39:21 PM
# 2   e15_Activated                   0.0  2024-06-22 05:07:06 PM
# 3       e1_Mobile                   NaN  2024-06-26 10:42:20 PM
# 4      e4_Payment                   NaN  2024-06-25 07:09:18 PM

# %% [markdown]
# ## **Task 2 - Fill 'e2_Email' in eKYC Stage Code colunm**

# %%
data_main["eKYC Stage Code"] = data_main['eKYC Stage Code'].fillna('e2_Email')

# %%
data_main['eKYC Stage Code'].isnull().sum()
# Out:
# 0

# %%
data_main.tail()
# Out:
#                                 Prospect ID Mobile Number    Phone Number  \
# 13314  6c202ecb-3603-44cb-9ccc-35855b15a388    8630651350   91 8630651350
# 13315  2f3a89c6-d486-4325-a41d-1d70759041d0    8005446039   91 8005446039
# 13316  21c2d6f4-5dbb-4910-86d2-24aa27ae59fb    8076044334   91 8076044334
# 13317  fe2793fb-5204-4239-b3b5-e7efc2d71ab4    6396955706   91 6396955706
# 13318  b00acab5-0781-4c21-b5cd-dd22f30616c0    6399931514   91 6399931514
#
#                            Email  \
# 13314       armanxlonn@gmail.com
# 13315     skitax.gupta@gmail.com
# 13316  poojateewari164@gmail.com
# 13317    rahuljativ427@gmail.com
# 13318         a3869673@gmail.com
#
#                                  Primary Source Campaign  \
# 13314                      Mr_Star_Sahil_YT1_28_May_2024
# 13315  Swing_Trader_-_The_Art_Of_Learning_YT_1_June_2024
# 13316                      DEFUSED_DEVIL_YT1_28_May_2024
# 13317                      DEFUSED_DEVIL_YT1_28_May_2024
# 13318                      Mr_Star_Sahil_YT1_28_May_2024
#
#               eKYC Stage Code  Total Payment Amount              Created On
# 13314  e14_Activation_Process                1207.0  2024-06-01 09:08:24 PM
# 13315              e4_Payment                2415.0  2024-06-01 07:20:50 PM
# 13316  e14_Activation_Process                1207.0  2024-06-01 01:39:57 PM
# 13317  e14_Activation_Process                1207.0  2024-06-01 04:39:22 PM
# 13318  e14_Activation_Process                   0.0  2024-06-01 01:21:47 PM

# %% [markdown]
# ## **Task 3 - Adding Vendors to the data from  vendors sheet using VLOOKUP()**

# %%
vendors_data = {
    'Primary Source Campaign': [
        'Bazar_Ke_Pandit_YT1_6_June_2024', 
        'Bazar_Ke_Pandit_YT1_6_June_2024', 
        'Diversify_knowledge_YT1_23_May_2024', 
        'Bazar_Ke_Pandit_YT1_6_June_2024', 
        'Trading_With_Karol_YT1_11_May_2024_{click_id}', 
        'Mr_Star_Sahil_YT1_28_May_2024', 
        'Swing_Trader_-_The_Art_Of_Learning_YT_1_June_2024',
        'DEFUSED_DEVIL_YT1_28_May_2024',
        'DEFUSED_DEVIL_YT1_28_May_2024',
        'Mr_Star_Sahil_YT1_28_May_2024'
    ],
    'Vendor Name': [
        'Vendor A', 
        'Vendor A', 
        'Vendor B', 
        'Vendor A', 
        'Vendor C', 
        'Vendor D', 
        'Vendor E',
        'Vendor F',
        'Vendor F',
        'Vendor D'
    ]
}

# %%
vendors = pd.DataFrame(vendors_data)

# Merge the data_main DataFrame with the vendors DataFrame on 'Primary Source Campaign'
data_main = data_main.merge(vendors, on='Primary Source Campaign', how='left')
# Out:
#                             Prospect ID Mobile Number    Phone Number Email  \
# 0  6cf3ad64-1e69-45f7-9cd9-0b1207149ded    9798394005   91 9798394005   NaN
# 1  6cf3ad64-1e69-45f7-9cd9-0b1207149ded    9798394005   91 9798394005   NaN
# 2  6cf3ad64-1e69-45f7-9cd9-0b1207149ded    9798394005   91 9798394005   NaN
# 3  51822e7e-b4a4-45ae-a000-3e043de211e6    7374996851   91 7374996851   NaN
# 4  51822e7e-b4a4-45ae-a000-3e043de211e6    7374996851   91 7374996851   NaN
#
#            Primary Source Campaign eKYC Stage Code  Total Payment Amount  \
# 0  Bazar_Ke_Pandit_YT1_6_June_2024       e1_Mobile                   NaN
# 1  Bazar_Ke_Pandit_YT1_6_June_2024       e1_Mobile                   NaN
# 2  Bazar_Ke_Pandit_YT1_6_June_2024       e1_Mobile                   NaN
# 3  Bazar_Ke_Pandit_YT1_6_June_2024       e1_Mobile                   NaN
# 4  Bazar_Ke_Pandit_YT1_6_June_2024       e1_Mobile                   NaN
#
#                Created On Vendor Name
# 0  2024-06-26 09:05:25 PM    Vendor A
# 1  2024-06-26 09:05:25 PM    Vendor A
# 2  2024-06-26 09:05:25 PM    Vendor A
# 3  2024-06-26 10:39:21 PM    Vendor A
# 4  2024-06-26 10:39:21 PM    Vendor A

# %%
data_main.head()
