# %% [markdown]
# # **Creating Automated Vendor Report Creation**

# %% [markdown]
# ## **importing packages**

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('Lead Report - 27th June.csv')
data.shape[0]
# Out:
# 13319

# %%
#data.columns.to_list()

# %%
data_main = data[['Prospect ID', 'Mobile Number','Phone Number', 'Email', 'Primary Source Campaign', 'eKYC Stage Code', 'Total Payment Amount', 'Created On']]
data_main.head()
# Out:
#                             Prospect ID  Mobile Number    Phone Number  \
# 0  6cf3ad64-1e69-45f7-9cd9-0b1207149ded   9.798394e+09   91 9798394005
# 1  51822e7e-b4a4-45ae-a000-3e043de211e6   7.374997e+09   91 7374996851
# 2  cc2b16d6-a198-44da-9b09-414dc491d80a   9.086708e+09   91 9086707739
# 3  f50a98d3-3a34-4fc3-ba45-b6ae72b60410   6.395005e+09   91 6395005269
# 4  e4fa7d46-a5ab-4540-bd8b-f42689f8f66f   9.988777e+09   91 9988777117
#
#                      Email                        Primary Source Campaign  \
# 0                      NaN                Bazar_Ke_Pandit_YT1_6_June_2024
# 1                      NaN                Bazar_Ke_Pandit_YT1_6_June_2024
# 2  morero7329@nolanzip.com            Diversify_knowledge_YT1_23_May_2024
# 3                      NaN                Bazar_Ke_Pandit_YT1_6_June_2024
# 4     sarabjil77@gmail.com  Trading_With_Karol_YT1_11_May_2024_{click_id}
#
#   eKYC Stage Code  Total Payment Amount              Created On
# 0       e1_Mobile                   NaN  2024-06-26 09:05:25 PM
# 1       e1_Mobile                   NaN  2024-06-26 10:39:21 PM
# 2   e15_Activated                   0.0  2024-06-22 05:07:06 PM
# 3       e1_Mobile                   NaN  2024-06-26 10:42:20 PM
# 4      e4_Payment                   NaN  2024-06-25 07:09:18 PM

# %%
data_main.columns.to_list()
# Out:
# ['Prospect ID',
#  'Mobile Number',
#  'Phone Number',
#  'Email',
#  'Primary Source Campaign',
#  'eKYC Stage Code',
#  'Total Payment Amount',
#  'Created On']

# %% [markdown]
# ## **Task 1 -Fill Mob No from Phone Number where Mob No is empty**

# %%
data_main.isnull().sum()
# Out:
# Prospect ID                   0
# Mobile Number                18
# Phone Number                  0
# Email                      6973
# Primary Source Campaign       0
# eKYC Stage Code              12
# Total Payment Amount       8212
# Created On                    0
# dtype: int64

# %%
# Function to extract the last 10 digits of the phone number
def extract_last_10_digits(phone):
    return str(phone)[-10:]

# %%
# Fill the null values in 'Mobile Number' with the last 10 digits of 'Phone Number'
data_main['Mobile Number'] = data_main.apply(
    lambda row: extract_last_10_digits(row['Phone Number']) if pd.isnull(row['Mobile Number']) or row['Mobile Number'] in ['None', 'nan'] else row['Mobile Number'],
    axis=1)

# Convert 'Mobile Number' to integer to remove any .0, then back to string
data_main['Mobile Number'] = data_main['Mobile Number'].apply(lambda x: str(int(float(x))))

# %%
data_main.head()
# Out:
#                             Prospect ID Mobile Number    Phone Number  \
# 0  6cf3ad64-1e69-45f7-9cd9-0b1207149ded    9798394005   91 9798394005
# 1  51822e7e-b4a4-45ae-a000-3e043de211e6    7374996851   91 7374996851
# 2  cc2b16d6-a198-44da-9b09-414dc491d80a    9086707739   91 9086707739
# 3  f50a98d3-3a34-4fc3-ba45-b6ae72b60410    6395005269   91 6395005269
# 4  e4fa7d46-a5ab-4540-bd8b-f42689f8f66f    9988777117   91 9988777117
#
#                      Email                        Primary Source Campaign  \
# 0                      NaN                Bazar_Ke_Pandit_YT1_6_June_2024
# 1                      NaN                Bazar_Ke_Pandit_YT1_6_June_2024
# 2  morero7329@nolanzip.com            Diversify_knowledge_YT1_23_May_2024
# 3                      NaN                Bazar_Ke_Pandit_YT1_6_June_2024
# 4     sarabjil77@gmail.com  Trading_With_Karol_YT1_11_May_2024_{click_id}
#
#   eKYC Stage Code  Total Payment Amount              Created On
# 0       e1_Mobile                   NaN  2024-06-26 09:05:25 PM
# 1       e1_Mobile                   NaN  2024-06-26 10:39:21 PM
# 2   e15_Activated                   0.0  2024-06-22 05:07:06 PM
# 3       e1_Mobile                   NaN  2024-06-26 10:42:20 PM
# 4      e4_Payment                   NaN  2024-06-25 07:09:18 PM

# %% [markdown]
# ## **Task 2 - Fill 'e2_Email' in eKYC Stage Code colunm**

# %%
data_main["eKYC Stage Code"] = data_main['eKYC Stage Code'].fillna('e2_Email')

# %%
data_main['eKYC Stage Code'].isnull().sum()
# Out:
# 0

# %%
data_main.head()
# Out:
#                             Prospect ID Mobile Number    Phone Number  \
# 0  6cf3ad64-1e69-45f7-9cd9-0b1207149ded    9798394005   91 9798394005
# 1  51822e7e-b4a4-45ae-a000-3e043de211e6    7374996851   91 7374996851
# 2  cc2b16d6-a198-44da-9b09-414dc491d80a    9086707739   91 9086707739
# 3  f50a98d3-3a34-4fc3-ba45-b6ae72b60410    6395005269   91 6395005269
# 4  e4fa7d46-a5ab-4540-bd8b-f42689f8f66f    9988777117   91 9988777117
#
#                      Email                        Primary Source Campaign  \
# 0                      NaN                Bazar_Ke_Pandit_YT1_6_June_2024
# 1                      NaN                Bazar_Ke_Pandit_YT1_6_June_2024
# 2  morero7329@nolanzip.com            Diversify_knowledge_YT1_23_May_2024
# 3                      NaN                Bazar_Ke_Pandit_YT1_6_June_2024
# 4     sarabjil77@gmail.com  Trading_With_Karol_YT1_11_May_2024_{click_id}
#
#   eKYC Stage Code  Total Payment Amount              Created On
# 0       e1_Mobile                   NaN  2024-06-26 09:05:25 PM
# 1       e1_Mobile                   NaN  2024-06-26 10:39:21 PM
# 2   e15_Activated                   0.0  2024-06-22 05:07:06 PM
# 3       e1_Mobile                   NaN  2024-06-26 10:42:20 PM
# 4      e4_Payment                   NaN  2024-06-25 07:09:18 PM

# %% [markdown]
# ## **Task 3 - Adding Vendors to the data from  vendors sheet using VLOOKUP()**

# %%
csv_url = 'https://docs.google.com/spreadsheets/d/1osDdsySYQdoBZlguvbb_UCZt2wfRbQvhSj8B2qa_RgU/export?format=csv'

vendors_data = pd.read_csv(csv_url, header=None)
# Set the first row as the header
vendors_data.columns = vendors_data.iloc[1]
vendors_data = vendors_data.drop([0, 1]).reset_index(drop=True)
vendors_data.head()
# Out:
# 1 Video Month                         Channel  \
# 0      Oct 23                       Trade2Day
# 1      Oct 23           Investment with Tarun
# 2      Oct 23  Stock Market का Badshah (SMkB)
# 3      Oct 23                  Knowledge Jazz
# 4     July 23                             NaN
#
# 1                                        Video Link     CTC  \
# 0                      https://youtu.be/_akShxeeUXM  30,000
# 1       https://youtu.be/wuAg1NtzRIo?feature=shared  40,000
# 2                      https://youtu.be/WoCGzwg6Jwg  20,000
# 3  https://youtu.be/U_T-gllIkww?si=PLyJ7PxUpWZHD2de  65,000
# 4                                               NaN     NaN
#
# 1 Expected Lead counts as per CTC  \
# 0                               7
# 1                               9
# 2                               4
# 3                              14
# 4                               0
#
# 1                                            YT Link  \
# 0  https://www.mstock.com/sem-landing/zero-broker...
# 1  https://www.mstock.com/sem-landing/zero-broker...
# 2  https://www.mstock.com/sem-landing/zero-broker...
# 3  https://www.mstock.com/sem-landing/zero-broker...
# 4                                                NaN
#
# 1                                        TG/YT1 Link  \
# 0  https://www.mstock.com/sem-landing/zero-broker...
# 1  https://www.mstock.com/sem-landing/zero-broker...
# 2  https://www.mstock.com/sem-landing/zero-broker...
# 3  https://www.mstock.com/sem-landing/zero-broker...
# 4                                                NaN
#
# 1                             NaN            TG/YT1 Bitly  \
# 0                       Trade2Day  https://bit.ly/3ruhw6t
# 1           Investment with Tarun  https://bit.ly/45gSFkc
# 2  Stock Market का Badshah (SMkB)  https://bit.ly/3RKfr0U
# 3                  Knowledge Jazz  https://bit.ly/46xKLnE
# 4                             NaN  https://bit.ly/3ZH1FOs
#
# 1                                      campaign  ...          Agency  Status  \
# 0                     Trade2Day_TG_03rd_October  ...             MRN  Paused
# 1    Investment_with_Tarun_TG_03rd_October_2023  ...             MRN  Paused
# 2  Stock_Market_ka_Badshah_TG_03rd_October_2023  ...             UTM  Paused
# 3           Knowledge_Jazz_TG_03rd_October_2023  ...             UTM  Paused
# 4                trade_swings_TG_15th_july_2023  ...  BS Enterprises  Paused
#
# 1 TG Leads YT Leads Inf Leads     CPC Old link Old Bitly old campaign name  \
# 0      NaN      NaN       NaN  30,000      NaN       NaN               NaN
# 1      NaN      NaN       NaN  40,000      NaN       NaN               NaN
# 2      NaN      NaN       NaN  20,000      NaN       NaN               NaN
# 3       29      NaN       NaN   2,241      NaN       NaN               NaN
# 4      NaN      NaN       NaN     NaN      NaN       NaN               NaN
#
# 1  NaN
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN
#
# [5 rows x 21 columns]

# %%
vendors_data_req = vendors_data[['TG/YT1 Bitly','campaign', 'Agency']]
vendors_data_req.columns= ['Bitly Link','Primary Source Campaign','agency']
vendors_data_req.head()
# Out:
#                Bitly Link                       Primary Source Campaign  \
# 0  https://bit.ly/3ruhw6t                     Trade2Day_TG_03rd_October
# 1  https://bit.ly/45gSFkc    Investment_with_Tarun_TG_03rd_October_2023
# 2  https://bit.ly/3RKfr0U  Stock_Market_ka_Badshah_TG_03rd_October_2023
# 3  https://bit.ly/46xKLnE           Knowledge_Jazz_TG_03rd_October_2023
# 4  https://bit.ly/3ZH1FOs                trade_swings_TG_15th_july_2023
#
#            agency
# 0             MRN
# 1             MRN
# 2             UTM
# 3             UTM
# 4  BS Enterprises

# %%
print(vendors_data_req.isna().sum())
print(vendors_data_req.shape[0])
# Out:
# Bitly Link                 361
# Primary Source Campaign    362
# agency                     541
# dtype: int64
# 1143

# %%
vendors_data_req.dropna(how='any', inplace=True)
print(vendors_data_req.isna().sum())
print(vendors_data_req.shape[0])
# Out:
# Bitly Link                 0
# Primary Source Campaign    0
# agency                     0
# dtype: int64
# 601

# %%
# Merge the data_main DataFrame with the vendors DataFrame on 'Primary Source Campaign'
data_merged = data_main.merge(vendors_data_req, on='Primary Source Campaign', how='left')
data_merged.tail()
# Out:
#                                 Prospect ID Mobile Number    Phone Number  \
# 13315  6c202ecb-3603-44cb-9ccc-35855b15a388    8630651350   91 8630651350
# 13316  2f3a89c6-d486-4325-a41d-1d70759041d0    8005446039   91 8005446039
# 13317  21c2d6f4-5dbb-4910-86d2-24aa27ae59fb    8076044334   91 8076044334
# 13318  fe2793fb-5204-4239-b3b5-e7efc2d71ab4    6396955706   91 6396955706
# 13319  b00acab5-0781-4c21-b5cd-dd22f30616c0    6399931514   91 6399931514
#
#                            Email  \
# 13315       armanxlonn@gmail.com
# 13316     skitax.gupta@gmail.com
# 13317  poojateewari164@gmail.com
# 13318    rahuljativ427@gmail.com
# 13319         a3869673@gmail.com
#
#                                  Primary Source Campaign  \
# 13315                      Mr_Star_Sahil_YT1_28_May_2024
# 13316  Swing_Trader_-_The_Art_Of_Learning_YT_1_June_2024
# 13317                      DEFUSED_DEVIL_YT1_28_May_2024
# 13318                      DEFUSED_DEVIL_YT1_28_May_2024
# 13319                      Mr_Star_Sahil_YT1_28_May_2024
#
#               eKYC Stage Code  Total Payment Amount              Created On  \
# 13315  e14_Activation_Process                1207.0  2024-06-01 09:08:24 PM
# 13316              e4_Payment                2415.0  2024-06-01 07:20:50 PM
# 13317  e14_Activation_Process                1207.0  2024-06-01 01:39:57 PM
# 13318  e14_Activation_Process                1207.0  2024-06-01 04:39:22 PM
# 13319  e14_Activation_Process                   0.0  2024-06-01 01:21:47 PM
#
#                    Bitly Link agency
# 13315  https://bit.ly/3wUvtx0     BS
# 13316                     NaN    NaN
# 13317  https://bit.ly/4543cRy     BS
# 13318  https://bit.ly/4543cRy     BS
# 13319  https://bit.ly/3wUvtx0     BS

# %%
data_merged.shape[0]
# Out:
# 13320

# %%
data_merged.isna().sum()
# Out:
# Prospect ID                   0
# Mobile Number                 0
# Phone Number                  0
# Email                      6973
# Primary Source Campaign       0
# eKYC Stage Code               0
# Total Payment Amount       8212
# Created On                    0
# Bitly Link                  998
# agency                      998
# dtype: int64

# %% [markdown]
# ## **Task 4 -Creating a new column Lead Stage**

# %%
# 
# a new column called lead stage 
# if eKYC has e12 OR e14 OR e15 then account opended AND Total Payment Amount is greater 100 then  
# else in proccess

# %%
data_merged['Total Payment Amount'].fillna(0, inplace=True)
data_merged.head()
# Out:
#                             Prospect ID Mobile Number    Phone Number  \
# 0  6cf3ad64-1e69-45f7-9cd9-0b1207149ded    9798394005   91 9798394005
# 1  51822e7e-b4a4-45ae-a000-3e043de211e6    7374996851   91 7374996851
# 2  cc2b16d6-a198-44da-9b09-414dc491d80a    9086707739   91 9086707739
# 3  f50a98d3-3a34-4fc3-ba45-b6ae72b60410    6395005269   91 6395005269
# 4  e4fa7d46-a5ab-4540-bd8b-f42689f8f66f    9988777117   91 9988777117
#
#                      Email                        Primary Source Campaign  \
# 0                      NaN                Bazar_Ke_Pandit_YT1_6_June_2024
# 1                      NaN                Bazar_Ke_Pandit_YT1_6_June_2024
# 2  morero7329@nolanzip.com            Diversify_knowledge_YT1_23_May_2024
# 3                      NaN                Bazar_Ke_Pandit_YT1_6_June_2024
# 4     sarabjil77@gmail.com  Trading_With_Karol_YT1_11_May_2024_{click_id}
#
#   eKYC Stage Code  Total Payment Amount              Created On  \
# 0       e1_Mobile                   0.0  2024-06-26 09:05:25 PM
# 1       e1_Mobile                   0.0  2024-06-26 10:39:21 PM
# 2   e15_Activated                   0.0  2024-06-22 05:07:06 PM
# 3       e1_Mobile                   0.0  2024-06-26 10:42:20 PM
# 4      e4_Payment                   0.0  2024-06-25 07:09:18 PM
#
#                Bitly Link agency
# 0  https://bit.ly/3KwIos7     BS
# 1  https://bit.ly/3KwIos7     BS
# 2  https://bit.ly/4521oYX     BS
# 3  https://bit.ly/3KwIos7     BS
# 4                     NaN    NaN

# %%
data_merged.insert(5, 'Lead Stage', None)
data_merged.head()
# Out:
#                             Prospect ID Mobile Number    Phone Number  \
# 0  6cf3ad64-1e69-45f7-9cd9-0b1207149ded    9798394005   91 9798394005
# 1  51822e7e-b4a4-45ae-a000-3e043de211e6    7374996851   91 7374996851
# 2  cc2b16d6-a198-44da-9b09-414dc491d80a    9086707739   91 9086707739
# 3  f50a98d3-3a34-4fc3-ba45-b6ae72b60410    6395005269   91 6395005269
# 4  e4fa7d46-a5ab-4540-bd8b-f42689f8f66f    9988777117   91 9988777117
#
#                      Email                        Primary Source Campaign  \
# 0                      NaN                Bazar_Ke_Pandit_YT1_6_June_2024
# 1                      NaN                Bazar_Ke_Pandit_YT1_6_June_2024
# 2  morero7329@nolanzip.com            Diversify_knowledge_YT1_23_May_2024
# 3                      NaN                Bazar_Ke_Pandit_YT1_6_June_2024
# 4     sarabjil77@gmail.com  Trading_With_Karol_YT1_11_May_2024_{click_id}
#
#   Lead Stage eKYC Stage Code  Total Payment Amount              Created On  \
# 0       None       e1_Mobile                   0.0  2024-06-26 09:05:25 PM
# 1       None       e1_Mobile                   0.0  2024-06-26 10:39:21 PM
# 2       None   e15_Activated                   0.0  2024-06-22 05:07:06 PM
# 3       None       e1_Mobile                   0.0  2024-06-26 10:42:20 PM
# 4       None      e4_Payment                   0.0  2024-06-25 07:09:18 PM
#
#                Bitly Link agency
# 0  https://bit.ly/3KwIos7     BS
# 1  https://bit.ly/3KwIos7     BS
# 2  https://bit.ly/4521oYX     BS
# 3  https://bit.ly/3KwIos7     BS
# 4                     NaN    NaN

# %%
# Define the generate_lead_stage function
def generate_lead_stage(row):
    ekyc_stage_code = row['eKYC Stage Code']
    total_payment_amount = row['Total Payment Amount']
    
    if 'e12' in ekyc_stage_code or 'e14' in ekyc_stage_code or 'e15' in ekyc_stage_code:
        if total_payment_amount > 100:
            return '999-Account Opened'
        else:
            return 'L4-Account Opened'
    else:
        return 'L2-in process'

# %%
data_merged['Lead Stage'] = data_merged.apply(generate_lead_stage, axis=1)
data_merged.head()
# Out:
#                             Prospect ID Mobile Number    Phone Number  \
# 0  6cf3ad64-1e69-45f7-9cd9-0b1207149ded    9798394005   91 9798394005
# 1  51822e7e-b4a4-45ae-a000-3e043de211e6    7374996851   91 7374996851
# 2  cc2b16d6-a198-44da-9b09-414dc491d80a    9086707739   91 9086707739
# 3  f50a98d3-3a34-4fc3-ba45-b6ae72b60410    6395005269   91 6395005269
# 4  e4fa7d46-a5ab-4540-bd8b-f42689f8f66f    9988777117   91 9988777117
#
#                      Email                        Primary Source Campaign  \
# 0                      NaN                Bazar_Ke_Pandit_YT1_6_June_2024
# 1                      NaN                Bazar_Ke_Pandit_YT1_6_June_2024
# 2  morero7329@nolanzip.com            Diversify_knowledge_YT1_23_May_2024
# 3                      NaN                Bazar_Ke_Pandit_YT1_6_June_2024
# 4     sarabjil77@gmail.com  Trading_With_Karol_YT1_11_May_2024_{click_id}
#
#           Lead Stage eKYC Stage Code  Total Payment Amount  \
# 0      L2-in process       e1_Mobile                   0.0
# 1      L2-in process       e1_Mobile                   0.0
# 2  L4-Account Opened   e15_Activated                   0.0
# 3      L2-in process       e1_Mobile                   0.0
# 4      L2-in process      e4_Payment                   0.0
#
#                Created On              Bitly Link agency
# 0  2024-06-26 09:05:25 PM  https://bit.ly/3KwIos7     BS
# 1  2024-06-26 10:39:21 PM  https://bit.ly/3KwIos7     BS
# 2  2024-06-22 05:07:06 PM  https://bit.ly/4521oYX     BS
# 3  2024-06-26 10:42:20 PM  https://bit.ly/3KwIos7     BS
# 4  2024-06-25 07:09:18 PM                     NaN    NaN

# %%
data_merged.isna().sum()
data_merged.shape[0]
# Out:
# 13320

# %%
data_merged.dropna(subset=['agency', 'Bitly Link'], inplace=True)
data_merged.head()
# Out:
#                             Prospect ID Mobile Number    Phone Number  \
# 0  6cf3ad64-1e69-45f7-9cd9-0b1207149ded    9798394005   91 9798394005
# 1  51822e7e-b4a4-45ae-a000-3e043de211e6    7374996851   91 7374996851
# 2  cc2b16d6-a198-44da-9b09-414dc491d80a    9086707739   91 9086707739
# 3  f50a98d3-3a34-4fc3-ba45-b6ae72b60410    6395005269   91 6395005269
# 5  01e1d861-1c09-4c29-9e09-1eb548516b4f    8999602739   91 8999602739
#
#                             Email              Primary Source Campaign  \
# 0                             NaN      Bazar_Ke_Pandit_YT1_6_June_2024
# 1                             NaN      Bazar_Ke_Pandit_YT1_6_June_2024
# 2         morero7329@nolanzip.com  Diversify_knowledge_YT1_23_May_2024
# 3                             NaN      Bazar_Ke_Pandit_YT1_6_June_2024
# 5  vaishnavichougule644@gmail.com         Your_iCircle_YT1_20_May_2024
#
#           Lead Stage eKYC Stage Code  Total Payment Amount  \
# 0      L2-in process       e1_Mobile                   0.0
# 1      L2-in process       e1_Mobile                   0.0
# 2  L4-Account Opened   e15_Activated                   0.0
# 3      L2-in process       e1_Mobile                   0.0
# 5      L2-in process      e4_Payment                   0.0
#
#                Created On              Bitly Link      agency
# 0  2024-06-26 09:05:25 PM  https://bit.ly/3KwIos7          BS
# 1  2024-06-26 10:39:21 PM  https://bit.ly/3KwIos7          BS
# 2  2024-06-22 05:07:06 PM  https://bit.ly/4521oYX          BS
# 3  2024-06-26 10:42:20 PM  https://bit.ly/3KwIos7          BS
# 5  2024-06-14 05:03:56 PM  https://bit.ly/4dLJhdX  Raghuvansh

# %%
data_merged.shape[0]
# Out:
# 12322

# %% [markdown]
# ## **dropping unused columns**

# %%
data_merged.drop(columns=['Prospect ID', 'Phone Number', 'Email'], inplace=True)
data_merged.head()
# Out:
#   Mobile Number              Primary Source Campaign         Lead Stage  \
# 0    9798394005      Bazar_Ke_Pandit_YT1_6_June_2024      L2-in process
# 1    7374996851      Bazar_Ke_Pandit_YT1_6_June_2024      L2-in process
# 2    9086707739  Diversify_knowledge_YT1_23_May_2024  L4-Account Opened
# 3    6395005269      Bazar_Ke_Pandit_YT1_6_June_2024      L2-in process
# 5    8999602739         Your_iCircle_YT1_20_May_2024      L2-in process
#
#   eKYC Stage Code  Total Payment Amount              Created On  \
# 0       e1_Mobile                   0.0  2024-06-26 09:05:25 PM
# 1       e1_Mobile                   0.0  2024-06-26 10:39:21 PM
# 2   e15_Activated                   0.0  2024-06-22 05:07:06 PM
# 3       e1_Mobile                   0.0  2024-06-26 10:42:20 PM
# 5      e4_Payment                   0.0  2024-06-14 05:03:56 PM
#
#                Bitly Link      agency
# 0  https://bit.ly/3KwIos7          BS
# 1  https://bit.ly/3KwIos7          BS
# 2  https://bit.ly/4521oYX          BS
# 3  https://bit.ly/3KwIos7          BS
# 5  https://bit.ly/4dLJhdX  Raghuvansh

# %% [markdown]
# ## **creating a pivot**

# %%
data_merged.columns = data_merged.columns.astype(str)
data_merged['Total Payment Amount'] = data_merged['Total Payment Amount'].astype('int64')
data_merged.dtypes
# Out:
# Mobile Number              object
# Primary Source Campaign    object
# Lead Stage                 object
# eKYC Stage Code            object
# Total Payment Amount        int64
# Created On                 object
# Bitly Link                 object
# agency                     object
# dtype: object

# %%
data_merged = data_merged.reset_index(drop=True)

# %%
data_merged_pivot = pd.pivot_table(data_merged, 
                                   index='Primary Source Campaign',
                                   columns='Lead Stage',
                                   values='Mobile Number',
                                   aggfunc='count',
                                   fill_value=0)
data_merged_pivot
# Out:
# Lead Stage                                          999-Account Opened  \
# Primary Source Campaign
# 7_Dreams_India_Official_YT1_5_June_2024                              0
# Abhuni_YT1_18_May_2024                                               0
# Akki_2op_YT1_16_May_2024                                            12
# AkshaT_YT1_29_May_2024                                               0
# Ankit_Jain_YT1_3_June_2024                                          61
# Atul_Patel_YT1_8_June_2024                                           0
# Bazar_Ke_Pandit_YT1_6_June_2024                                     89
# Bull_Earner_YT1_2_June_2024                                          0
# Chaudhary_Tips_YT1_4_May_2024                                        0
# DEFUSED_DEVIL_YT1_28_May_2024                                      136
# DEFUSED_LIVE_YT1_29_May_2024                                         0
# Digital_Expert_YT1_28_May_2024                                      54
# Diversify_knowledge_YT1_13_June_2024                                 0
# Diversify_knowledge_YT1_23_May_2024                                 35
# Geek_Abhishek_YT1_17_May_2024                                       67
# Goblin_YT1_28_May_2024                                               0
# Harsh_Earning_Tips_YT1_5_December_2023                               0
# INFO_Mindset_YT1_17_May_2024                                         0
# INFO_Mindset_YT1_3_June_2024                                         7
# Invest_wid_Deepak_YT1_5_June_2024                                    0
# Investment_king_YT1_6_June_2024                                      3
# Market_Trader_YT1_10_June_2024                                     50
# Money_Talks_With_Payal_YT1_3_June_2024                              1
# Mr._Rishi_YT1_27_May_2024                                           3
# MrJadoo_YT1_23_May_2024                                           217
# Mr_Star_Sahil_YT1_28_May_2024                                     112
# Niz_Unfiltered_YT1_18_June_2024                                     1
# Pravin_Khetan_YT1_5_June_2024                                       9
# Punji_Guide_YT1_1_June_2024                                         0
# Ride_with_Vj_YT1_13_May_2024                                       35
# SOUVIK_D_YT1_7_May_2024                                             5
# Satvinder_Narwal_YT1_8_June_2024                                    0
# SenpaiExtras_YT1_29_May_2024                                       43
# Share_Market_Analysis_YT1_11_June_2024                             12
# Share_Market_Analysis_YT1_11_May_2024                               0
# Siddharth_Bhat_YT1_3_June_2024                                      1
# Sm_Investor_YT1_6_June_2024                                         1
# Stock247_YT1_18_May_2024                                            1
# Stock_Learners_YT1_8_June_2024                                      1
# Sunday_Nivesh_YT1_19_May_2024                                       0
# Sunday_Nivesh_YT1_3_June_2024                                     183
# Swing_Trader_-_The_Art_Of_Learning_YT1_1_June_2024                  2
# Swing_Trader_-_The_Art_Of_Learning_YT1_3_May_2024                   0
# Tech_RJ_YT1_19_May_2024                                           141
# Technical_Shubham_YT1_12_April_2024                                 0
# Technical_Shubham_YT1_21_May_2024                                 119
# Telugu_guy_reacts_YT1_14_May_2024                                  14
# Vivek_Singh_Rana_YT1_1_June_2024                                   43
# Your_iCircle_YT1_20_May_2024                                      404
# Yug_2.0_YT1_12_May_2024                                           163
# iFlicks_YT1_19_May_2024                                            25
# myBiniyog_YT1_18_June_2024                                          3

# %%
print(data_merged_pivot.shape[0])
print(data_merged['Primary Source Campaign'].nunique())
# Out:
# 58
# 58

# %%
sum_row = data_merged_pivot.sum()
sum_row.name = 'Total'
data_merged_pivot = pd.concat([data_merged_pivot, pd.DataFrame(sum_row).T])

# %%
data_merged_pivot = data_merged_pivot.reset_index()
data_merged_pivot.tail()
# Out:
# Lead Stage                         index  999-Account Opened  L2-in process  \
# 54          Your_iCircle_YT1_20_May_2024                   0            386
# 55               Yug_2.0_YT1_12_May_2024                   0            769
# 56               iFlicks_YT1_19_May_2024                   0              0
# 57            myBiniyog_YT1_18_June_2024                  17              4
# 58                                 Total                1324           8251
#
# Lead Stage  L4-Account Opened
# 54                        404
# 55                        163
# 56                         25
# 57                          3
# 58                       2747

# %%
# Rename the columns as needed
data_merged_pivot.columns.name = None
data_merged_pivot.columns = ['Primary Source Campaign', '999-Account Opened', 'L2-in process', 'L4-Account Opened']
data_merged_pivot.head()
# Out:
#                    Primary Source Campaign  999-Account Opened  L2-in process  \
# 0  7_Dreams_India_Official_YT1_5_June_2024                   0              1
# 1                   Abhuni_YT1_18_May_2024                   0              4
# 2                 Akki_2op_YT1_16_May_2024                  12             10
# 3                   AkshaT_YT1_29_May_2024                   0              8
# 4               Ankit_Jain_YT1_3_June_2024                  61            904
#
#    L4-Account Opened
# 0                  1
# 1                  0
# 2                  0
# 3                 58
# 4                147

# %% [markdown]
# ## **merging the Bitly Link	with Pivot**

# %%
# Create a dictionary to map 'Primary Source Campaign' to 'Bitly Link'
campaign_to_bitly = data_merged.set_index('Primary Source Campaign')['Bitly Link'].to_dict()

# %%
# Add 'Bitly Link' column to data_merged_pivot by mapping
data_merged_pivot['Bitly Link'] = data_merged_pivot['Primary Source Campaign'].map(campaign_to_bitly)

# %%
data_merged_pivot.shape[0]
# Out:
# 59

# %%
data_merged_pivot
# Out:
#                               Primary Source Campaign  999-Account Opened  \
# 0             7_Dreams_India_Official_YT1_5_June_2024                   0
# 1                              Abhuni_YT1_18_May_2024                   0
# 2                            Akki_2op_YT1_16_May_2024                  12
# 3                              AkshaT_YT1_29_May_2024                   0
# 4                          Ankit_Jain_YT1_3_June_2024                  61
# 5                          Atul_Patel_YT1_8_June_2024                   0
# 6                     Bazar_Ke_Pandit_YT1_6_June_2024                  89
# 7                         Bull_Earner_YT1_2_June_2024                   0
# 8                       Chaudhary_Tips_YT1_4_May_2024                   0
# 9                       DEFUSED_DEVIL_YT1_28_May_2024                 136
# 10                       DEFUSED_LIVE_YT1_29_May_2024                   0
# 11                     Digital_Expert_YT1_28_May_2024                  54
# 12               Diversify_knowledge_YT1_13_June_2024                   0
# 13                Diversify_knowledge_YT1_23_May_2024                  35
# 14                      Geek_Abhishek_YT1_17_May_2024                  67
# 15                             Goblin_YT1_28_May_2024                   0
# 16             Harsh_Earning_Tips_YT1_5_December_2023                   0
# 17                       INFO_Mindset_YT1_17_May_2024                   0
# 18                       INFO_Mindset_YT1_3_June_2024                   7
# 19                  Invest_wid_Deepak_YT1_5_June_2024                   0
# 20                    Investment_king_YT1_6_June_2024                   3
# 21                     Investors_Adda_YT1_6_June_2024                 234
# 22                     Knowledge_Jazz_YT1_22_May_2024                  25
# 23                     Lakshay_Chopra_YT1_27_May_2024                   1
# 24                     Logical_Trader_YT1_4_June_2024                   0
# 25                MS_Trading_Analysis_YT1_10_May_2024                   0
# 26                     Market_Support_YT1_3_June_2024                   1
# 27                     Market_Trader_YT1_10_June_2024                  15
# 28             Money_Talks_With_Payal_YT1_3_June_2024                  26
# 29                          Mr._Rishi_YT1_27_May_2024                  70
# 30                            MrJadoo_YT1_23_May_2024                   0
# 31                      Mr_Star_Sahil_YT1_28_May_2024                  55
# 32                    Niz_Unfiltered_YT1_18_June_2024                  22
# 33                      Pravin_Khetan_YT1_5_June_2024                   0
# 34                        Punji_Guide_YT1_1_June_2024                   0
# 35                       Ride_with_Vj_YT1_13_May_2024                   0
# 36                            SOUVIK_D_YT1_7_May_2024                  46
# 37                   Satvinder_Narwal_YT1_8_June_2024                   0
# 38                       SenpaiExtras_YT1_29_May_2024                   0
# 39             Share_Market_Analysis_YT1_11_June_2024                 133
# 40              Share_Market_Analysis_YT1_11_May_2024                   1
# 41                     Siddharth_Bhat_YT1_3_June_2024                   0
# 42                        Sm_Investor_YT1_6_June_2024                   0
# 43                           Stock247_YT1_18_May_2024                   0
# 44                     Stock_Learners_YT1_8_June_2024                   0
# 45                      Sunday_Nivesh_YT1_19_May_2024                   5
# 46                      Sunday_Nivesh_YT1_3_June_2024                   0
# 47  Swing_Trader_-_The_Art_Of_Learning_YT1_1_June_...                   0
# 52             12                 14  https://bit.ly/3K4wzcs
# 53            302                 43  https://bit.ly/3wRxVEK
# 54            386                404  https://bit.ly/4dLJhdX
# 55            769                163  https://bit.ly/4dNsffA
# 56              0                 25  https://bit.ly/3yvNi67
# 57              4                  3  https://bit.ly/45xZb7O
# 58           8251               2747                     NaN

# %% [markdown]
# ## **Coverting all results to EXCEL File**

# %%
with pd.ExcelWriter('excel files//output.xlsx', engine='xlsxwriter') as writer:
    data_merged.to_excel(writer, sheet_name='Data Cleaned', index=False)
    data_merged_pivot.to_excel(writer, sheet_name='Pivot', index=False)

# %% [markdown]
# ## **Creating Agency wise Everything**

# %%
agency_groups = data_merged.groupby('agency')
agency_dfs = {agency: group.drop(columns=['agency']) for agency, group in agency_groups}

# %%
list_of_agency = []
list_of_agency_df = []
for agency, df in agency_dfs.items():
    list_of_agency.append(agency)
    list_of_agency_df.append(df)

print(list_of_agency)
#print(list_of_agency_df)
# Out:
# ['BS', 'Cashjosh', 'Dheerendra raj', 'Flickstree', 'Raghuvansh', 'digital ads media', 'pahi-j']

# %%
list_of_agency_df[0]
# Out:
#       Mobile Number              Primary Source Campaign          Lead Stage  \
# 0        9798394005      Bazar_Ke_Pandit_YT1_6_June_2024       L2-in process
# 1        7374996851      Bazar_Ke_Pandit_YT1_6_June_2024       L2-in process
# 2        9086707739  Diversify_knowledge_YT1_23_May_2024   L4-Account Opened
# 3        6395005269      Bazar_Ke_Pandit_YT1_6_June_2024       L2-in process
# 5        8435013045      Bazar_Ke_Pandit_YT1_6_June_2024       L2-in process
# ...             ...                                  ...                 ...
# 12316    8130721311        DEFUSED_DEVIL_YT1_28_May_2024  999-Account Opened
# 12318    8630651350        Mr_Star_Sahil_YT1_28_May_2024  999-Account Opened
# 12319    8076044334        DEFUSED_DEVIL_YT1_28_May_2024  999-Account Opened
# 12320    6396955706        DEFUSED_DEVIL_YT1_28_May_2024  999-Account Opened
# 12321    6399931514        Mr_Star_Sahil_YT1_28_May_2024   L4-Account Opened
#
#               eKYC Stage Code  Total Payment Amount              Created On  \
# 0                   e1_Mobile                     0  2024-06-26 09:05:25 PM
# 1                   e1_Mobile                     0  2024-06-26 10:39:21 PM
# 2               e15_Activated                     0  2024-06-22 05:07:06 PM
# 3                   e1_Mobile                     0  2024-06-26 10:42:20 PM
# 5                   e1_Mobile                     0  2024-06-25 10:45:51 PM
# ...                       ...                   ...                     ...
# 12316           e15_Activated                  1207  2024-06-01 02:03:15 PM
# 12318  e14_Activation_Process                  1207  2024-06-01 09:08:24 PM
# 12319  e14_Activation_Process                  1207  2024-06-01 01:39:57 PM
# 12320  e14_Activation_Process                  1207  2024-06-01 04:39:22 PM
# 12321  e14_Activation_Process                     0  2024-06-01 01:21:47 PM
#
#                    Bitly Link
# 0      https://bit.ly/3KwIos7
# 1      https://bit.ly/3KwIos7
# 2      https://bit.ly/4521oYX
# 3      https://bit.ly/3KwIos7
# 5      https://bit.ly/3KwIos7
# ...                       ...
# 12316  https://bit.ly/4543cRy
# 12318  https://bit.ly/3wUvtx0
# 12319  https://bit.ly/4543cRy
# 12320  https://bit.ly/4543cRy
# 12321  https://bit.ly/3wUvtx0
#
# [9405 rows x 7 columns]

# %%
list_of_agency_df[0].columns
# Out:
# Index(['Mobile Number', 'Primary Source Campaign', 'Lead Stage',
#        'eKYC Stage Code', 'Total Payment Amount', 'Created On', 'Bitly Link'],
#       dtype='object')

# %%
pivoted_df = []
for each_df in list_of_agency_df:
    each_df_pivot = pd.pivot_table(each_df, index='Primary Source Campaign', columns='Lead Stage', values='Mobile Number', aggfunc='count', fill_value=0)

    # adding a row of TOTAL
    sum_row = each_df_pivot.sum()
    sum_row.name = 'TOTAL'
    each_df_pivot = pd.concat([each_df_pivot, pd.DataFrame(sum_row).T])

    # Reset the index to make 'Primary Source Campaign' a regular column
    each_df_pivot = each_df_pivot.reset_index()

    # Ensure all desired columns are present
    required_columns = ['999-Account Opened', 'L2-in process', 'L4-Account Opened']
    for col in required_columns:
        if col not in each_df_pivot.columns:
            each_df_pivot[col] = 0

    # Reorder the columns
    # each_df_pivot = each_df_pivot[['Primary Source Campaign'] + required_columns]

    # merging Bitly Links to it ---- # Create a dictionary to map 'Primary Source Campaign' to 'Bitly Link'
    campaign_to_bitly = data_merged.set_index('Primary Source Campaign')['Bitly Link'].to_dict()

    # Add 'Bitly Link' column to data_merged_pivot by mapping
    each_df_pivot['Bitly Link'] = data_merged['Primary Source Campaign'].map(campaign_to_bitly)
    each_df_pivot.rename(columns={'index':'Primary Source Campaign'}, inplace=True)
    
    pivoted_df.append(each_df_pivot)

agency_pivotdf_dict = agency_dfs.copy()
agency_pivotdf_dict.update(dict(zip(agency_dfs.keys(), pivoted_df)))

# %%
pivoted_df[0]
# Out:
# Lead Stage                            Primary Source Campaign  \
# 0                                      AkshaT_YT1_29_May_2024
# 1                                  Ankit_Jain_YT1_3_June_2024
# 2                                  Atul_Patel_YT1_8_June_2024
# 3                             Bazar_Ke_Pandit_YT1_6_June_2024
# 4                               DEFUSED_DEVIL_YT1_28_May_2024
# 5                                DEFUSED_LIVE_YT1_29_May_2024
# 6                         Diversify_knowledge_YT1_23_May_2024
# 7                                INFO_Mindset_YT1_3_June_2024
# 8                              Investors_Adda_YT1_6_June_2024
# 9                         MS_Trading_Analysis_YT1_10_May_2024
# 10                             Market_Trader_YT1_10_June_2024
# 11                     Money_Talks_With_Payal_YT1_3_June_2024
# 12                                    MrJadoo_YT1_23_May_2024
# 13                              Mr_Star_Sahil_YT1_28_May_2024
# 14                            Niz_Unfiltered_YT1_18_June_2024
# 15                                Punji_Guide_YT1_1_June_2024
# 16                               Ride_with_Vj_YT1_13_May_2024
# 17                               SenpaiExtras_YT1_29_May_2024
# 18                     Share_Market_Analysis_YT1_11_June_2024
# 19                             Siddharth_Bhat_YT1_3_June_2024
# 20                             Stock_Learners_YT1_8_June_2024
# 21                              Sunday_Nivesh_YT1_3_June_2024
# 22          Swing_Trader_-_The_Art_Of_Learning_YT1_1_June_...
# 23                           Vivek_Singh_Rana_YT1_1_June_2024
# 24                                    Yug_2.0_YT1_12_May_2024
# 25                                 myBiniyog_YT1_18_June_2024
# 26                                                      TOTAL
#
# Lead Stage  999-Account Opened  L2-in process  L4-Account Opened  \
# 0                            0              8                 58
# 1                           61            904                147
# 2                            0              1                 50
# 3                           89            336                 59
# 4                          136            520                 24
# 5                            0              4                 45
# 6                           35            967                178
# 7                            7              5                  7
# 8                          234             34                 24
# 9                            0            632                131
# 10                          15              2                 50
# 11                          26              0                  1
# 12                           0            637                217
# 13                          55            573                112
# 14                          22              7                  1
# 15                           0            313                  0
# 16                           0              4                 35
# 17                           0             89                 43
# 18                         133             34                 12
# 19                           0            328                  1
# 20                           0              2                  1
# 21                           0             34                183
# 22                           0            291                  2
# 23                         185            302                 43
# 24                           0            769                163
# 25                          17              4                  3
# 26                        1015           6800               1590
#
# Lead Stage              Bitly Link
# 0           https://bit.ly/3KwIos7
# 1           https://bit.ly/3KwIos7
# 2           https://bit.ly/4521oYX
# 3           https://bit.ly/3KwIos7
# 4           https://bit.ly/4dLJhdX
# 5           https://bit.ly/3KwIos7
# 6           https://bit.ly/3x4r4Yp
# 7           https://bit.ly/3x4r4Yp
# 8           https://bit.ly/3KwIos7
# 9           https://bit.ly/3KwIos7
# 10          https://bit.ly/45qCnqx
# 11          https://bit.ly/4dLJhdX
# 12          https://bit.ly/4bNUHfO
# 13          https://bit.ly/3VE7NGV
# 14          https://bit.ly/4dLJhdX
# 15          https://bit.ly/3x4r4Yp
# 16          https://bit.ly/3JNXIAu
# 17          https://bit.ly/3WOQjs7
# 18          https://bit.ly/3WOQjs7
# 19          https://bit.ly/45qCnqx
# 20          https://bit.ly/3V83TWh
# 21          https://bit.ly/3Vhjlja
# 22          https://bit.ly/3VE7NGV
# 23          https://bit.ly/3x4r4Yp
# 24          https://bit.ly/4dLJhdX
# 25          https://bit.ly/3x4r4Yp
# 26          https://bit.ly/3x4r4Yp

# %%
#def craete_excel(dict):
with pd.ExcelWriter('excel files//output.xlsx', engine='xlsxwriter') as writer:
    for key, value in agency_pivotdf_dict.items():
        value.to_excel(writer, sheet_name=str(key), index=False)

# %%
pd.pivot_table(list_of_agency_df[0], index='Primary Source Campaign', columns='Lead Stage', values='Mobile Number', aggfunc='count', fill_value=0)
# Out:
# Lead Stage                             999-Account Opened  L2-in process  \
# Primary Source Campaign
# Alok_Games_YT1_14_June_2024                             0              0
# Bull_Earner_YT1_2_July_2024                             0              3
# My_stock_World_YT1_18_June_2024                        18              5
# Share_Market_Analysis_YT1_1_July_2024                   0              1
# Snehilop_Gaming_YT1_15_June_2024                       30              3
# The_mini_trader_YT1_2_July_2024                         0             21
# Vivek_Singh_Rana_YT1_1_June_2024                        0              2
#
# Lead Stage                             L4-Account Opened
# Primary Source Campaign
# Alok_Games_YT1_14_June_2024                            1
# Bull_Earner_YT1_2_July_2024                            6
# My_stock_World_YT1_18_June_2024                       12
# Share_Market_Analysis_YT1_1_July_2024                 10
# Snehilop_Gaming_YT1_15_June_2024                       2
# The_mini_trader_YT1_2_July_2024                       27
# Vivek_Singh_Rana_YT1_1_June_2024                       0

# %%
agency_dfs.keys()
# Out:
# dict_keys(['BS', 'Cashjosh', 'Dheerendra raj', 'Fasto', 'MediaXPedia', 'Pahi-j', 'Raghuvansh', 'affilienet'])
