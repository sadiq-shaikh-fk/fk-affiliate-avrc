# %% [markdown]
# # **Creating Automated Vendor Report Creation**

# %% [markdown]
# ## **importing packages**

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
path = "C:\\Users\\hp\\Downloads\\Lead Report - 9th July.csv"

# %%
data = pd.read_csv(path)
data.shape[0]
# Out:
# 2751

# %%
#data.columns.to_list()

# %%
data_main = data[['Prospect ID', 'Mobile Number','Phone Number', 'Email', 'Primary Source Campaign', 'eKYC Stage Code', 'Total Payment Amount', 'Created On']]
data_main.head()
# Out:
#                             Prospect ID  Mobile Number    Phone Number  \
# 0  367ad3f4-f682-4b5b-bd59-271b060f3cdf     8217253062   91 8217253062
# 1  d5d6a80b-31d3-4bdb-aa29-53bc5562f940     8191999195   91 8191999195
# 2  b186afee-9c26-4d9d-bacd-5ba0c5d63321     7037092729   91 7037092729
# 3  a6f2ccf1-742f-43b1-b46f-b2dbf22233b4     9927263738   91 9927263738
# 4  5fa98042-50b8-4bfd-8c50-0f77c87b31a7     7617651326   91 7617651326
#
#                        Email  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3    khushimbd2019@gmail.com
# 4  yogeshpal121199@gmail.com
#
#                              Primary Source Campaign         eKYC Stage Code  \
# 0                  Vivek_Singh_Rana_YT1_12_June_2024               e1_Mobile
# 1                   Snehilop_Gaming_YT1_15_June_2024               e1_Mobile
# 2  Money_Talks_With_Payal_YT1_1_July_2024_e348b33...               e1_Mobile
# 3                        Rs_Fintech_YT1_13_June_2024               e12_eSign
# 4                   Snehilop_Gaming_YT1_15_June_2024  e14_Activation_Process
#
#    Total Payment Amount              Created On
# 0                   NaN  2024-07-07 12:31:05 PM
# 1                   NaN  2024-07-07 12:40:25 PM
# 2                   NaN  2024-07-08 04:02:06 PM
# 3                   0.0  2024-07-06 10:37:02 PM
# 4                1207.0  2024-07-07 11:05:14 AM

# %%
data_main.columns.to_list()
# Out:
# ['Prospect ID',
#  'Mobile Number',
#  'Phone Number',
#  'Email',
#  'Primary Source Campaign',
#  'eKYC Stage Code',
#  'Total Payment Amount',
#  'Created On']

# %% [markdown]
# ## **Task 1 -Fill Mob No from Phone Number where Mob No is empty**

# %%
data_main.isnull().sum()
# Out:
# Prospect ID                   0
# Mobile Number                 0
# Phone Number                  0
# Email                       984
# Primary Source Campaign       0
# eKYC Stage Code               0
# Total Payment Amount       1445
# Created On                    0
# dtype: int64

# %%
# Function to extract the last 10 digits of the phone number
def extract_last_10_digits(phone):
    return str(phone)[-10:]

# %%
# Fill the null values in 'Mobile Number' with the last 10 digits of 'Phone Number'
data_main['Mobile Number'] = data_main.apply(
    lambda row: extract_last_10_digits(row['Phone Number']) if pd.isnull(row['Mobile Number']) or row['Mobile Number'] in ['None', 'nan'] else row['Mobile Number'],
    axis=1)

# Convert 'Mobile Number' to integer to remove any .0, then back to string
data_main['Mobile Number'] = data_main['Mobile Number'].apply(lambda x: str(int(float(x))))

# %%
data_main.head()
# Out:
#                             Prospect ID Mobile Number    Phone Number  \
# 0  367ad3f4-f682-4b5b-bd59-271b060f3cdf    8217253062   91 8217253062
# 1  d5d6a80b-31d3-4bdb-aa29-53bc5562f940    8191999195   91 8191999195
# 2  b186afee-9c26-4d9d-bacd-5ba0c5d63321    7037092729   91 7037092729
# 3  a6f2ccf1-742f-43b1-b46f-b2dbf22233b4    9927263738   91 9927263738
# 4  5fa98042-50b8-4bfd-8c50-0f77c87b31a7    7617651326   91 7617651326
#
#                        Email  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3    khushimbd2019@gmail.com
# 4  yogeshpal121199@gmail.com
#
#                              Primary Source Campaign         eKYC Stage Code  \
# 0                  Vivek_Singh_Rana_YT1_12_June_2024               e1_Mobile
# 1                   Snehilop_Gaming_YT1_15_June_2024               e1_Mobile
# 2  Money_Talks_With_Payal_YT1_1_July_2024_e348b33...               e1_Mobile
# 3                        Rs_Fintech_YT1_13_June_2024               e12_eSign
# 4                   Snehilop_Gaming_YT1_15_June_2024  e14_Activation_Process
#
#    Total Payment Amount              Created On
# 0                   NaN  2024-07-07 12:31:05 PM
# 1                   NaN  2024-07-07 12:40:25 PM
# 2                   NaN  2024-07-08 04:02:06 PM
# 3                   0.0  2024-07-06 10:37:02 PM
# 4                1207.0  2024-07-07 11:05:14 AM

# %% [markdown]
# ## **Task 2 - Fill 'e2_Email' in eKYC Stage Code colunm**

# %%
data_main["eKYC Stage Code"] = data_main['eKYC Stage Code'].fillna('e2_Email')

# %%
data_main['eKYC Stage Code'].isnull().sum()
# Out:
# 0

# %%
data_main.head()
# Out:
#                             Prospect ID Mobile Number    Phone Number  \
# 0  367ad3f4-f682-4b5b-bd59-271b060f3cdf    8217253062   91 8217253062
# 1  d5d6a80b-31d3-4bdb-aa29-53bc5562f940    8191999195   91 8191999195
# 2  b186afee-9c26-4d9d-bacd-5ba0c5d63321    7037092729   91 7037092729
# 3  a6f2ccf1-742f-43b1-b46f-b2dbf22233b4    9927263738   91 9927263738
# 4  5fa98042-50b8-4bfd-8c50-0f77c87b31a7    7617651326   91 7617651326
#
#                        Email  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3    khushimbd2019@gmail.com
# 4  yogeshpal121199@gmail.com
#
#                              Primary Source Campaign         eKYC Stage Code  \
# 0                  Vivek_Singh_Rana_YT1_12_June_2024               e1_Mobile
# 1                   Snehilop_Gaming_YT1_15_June_2024               e1_Mobile
# 2  Money_Talks_With_Payal_YT1_1_July_2024_e348b33...               e1_Mobile
# 3                        Rs_Fintech_YT1_13_June_2024               e12_eSign
# 4                   Snehilop_Gaming_YT1_15_June_2024  e14_Activation_Process
#
#    Total Payment Amount              Created On
# 0                   NaN  2024-07-07 12:31:05 PM
# 1                   NaN  2024-07-07 12:40:25 PM
# 2                   NaN  2024-07-08 04:02:06 PM
# 3                   0.0  2024-07-06 10:37:02 PM
# 4                1207.0  2024-07-07 11:05:14 AM

# %% [markdown]
# ## **Task 3 - Adding Vendors to the data from  vendors sheet using VLOOKUP()**

# %%
csv_url = 'https://docs.google.com/spreadsheets/d/1osDdsySYQdoBZlguvbb_UCZt2wfRbQvhSj8B2qa_RgU/export?format=csv'

vendors_data = pd.read_csv(csv_url, header=None)
# Set the first row as the header
vendors_data.columns = vendors_data.iloc[1]
vendors_data = vendors_data.drop([0, 1]).reset_index(drop=True)
vendors_data.head()
# Out:
# 1 Video Month                         Channel  \
# 0      Oct 23                       Trade2Day
# 1      Oct 23           Investment with Tarun
# 2      Oct 23  Stock Market का Badshah (SMkB)
# 3      Oct 23                  Knowledge Jazz
# 4     July 23                             NaN
#
# 1                                        Video Link     CTC  \
# 0                      https://youtu.be/_akShxeeUXM  30,000
# 1       https://youtu.be/wuAg1NtzRIo?feature=shared  40,000
# 2                      https://youtu.be/WoCGzwg6Jwg  20,000
# 3  https://youtu.be/U_T-gllIkww?si=PLyJ7PxUpWZHD2de  65,000
# 4                                               NaN     NaN
#
# 1 Expected Lead counts as per CTC  \
# 0                               7
# 1                               9
# 2                               4
# 3                              14
# 4                               0
#
# 1                                            YT Link  \
# 0  https://www.mstock.com/sem-landing/zero-broker...
# 1  https://www.mstock.com/sem-landing/zero-broker...
# 2  https://www.mstock.com/sem-landing/zero-broker...
# 3  https://www.mstock.com/sem-landing/zero-broker...
# 4                                                NaN
#
# 1                                        TG/YT1 Link  \
# 0  https://www.mstock.com/sem-landing/zero-broker...
# 1  https://www.mstock.com/sem-landing/zero-broker...
# 2  https://www.mstock.com/sem-landing/zero-broker...
# 3  https://www.mstock.com/sem-landing/zero-broker...
# 4                                                NaN
#
# 1                             NaN            TG/YT1 Bitly  \
# 0                       Trade2Day  https://bit.ly/3ruhw6t
# 1           Investment with Tarun  https://bit.ly/45gSFkc
# 2  Stock Market का Badshah (SMkB)  https://bit.ly/3RKfr0U
# 3                  Knowledge Jazz  https://bit.ly/46xKLnE
# 4                             NaN  https://bit.ly/3ZH1FOs
#
# 1                                      campaign  ...          Agency  Status  \
# 0                     Trade2Day_TG_03rd_October  ...             MRN  Paused
# 1    Investment_with_Tarun_TG_03rd_October_2023  ...             MRN  Paused
# 2  Stock_Market_ka_Badshah_TG_03rd_October_2023  ...             UTM  Paused
# 3           Knowledge_Jazz_TG_03rd_October_2023  ...             UTM  Paused
# 4                trade_swings_TG_15th_july_2023  ...  BS Enterprises  Paused
#
# 1 TG Leads YT Leads Inf Leads     CPC Old link Old Bitly old campaign name  \
# 0      NaN      NaN       NaN  30,000      NaN       NaN               NaN
# 1      NaN      NaN       NaN  40,000      NaN       NaN               NaN
# 2      NaN      NaN       NaN  20,000      NaN       NaN               NaN
# 3       29      NaN       NaN   2,241      NaN       NaN               NaN
# 4      NaN      NaN       NaN     NaN      NaN       NaN               NaN
#
# 1  NaN
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN
#
# [5 rows x 21 columns]

# %%
vendors_data_req = vendors_data[['TG/YT1 Bitly','campaign', 'Agency']]
vendors_data_req.columns= ['Bitly Link','Primary Source Campaign','agency']
vendors_data_req.head()
# Out:
#                Bitly Link                       Primary Source Campaign  \
# 0  https://bit.ly/3ruhw6t                     Trade2Day_TG_03rd_October
# 1  https://bit.ly/45gSFkc    Investment_with_Tarun_TG_03rd_October_2023
# 2  https://bit.ly/3RKfr0U  Stock_Market_ka_Badshah_TG_03rd_October_2023
# 3  https://bit.ly/46xKLnE           Knowledge_Jazz_TG_03rd_October_2023
# 4  https://bit.ly/3ZH1FOs                trade_swings_TG_15th_july_2023
#
#            agency
# 0             MRN
# 1             MRN
# 2             UTM
# 3             UTM
# 4  BS Enterprises

# %%
print(vendors_data_req.isna().sum())
print(vendors_data_req.shape[0])
# Out:
# Bitly Link                 326
# Primary Source Campaign    327
# agency                     528
# dtype: int64
# 1143

# %%
vendors_data_req.dropna(how='any', inplace=True)
print(vendors_data_req.isna().sum())
print(vendors_data_req.shape[0])
# Out:
# Bitly Link                 0
# Primary Source Campaign    0
# agency                     0
# dtype: int64
# 614

# %%
# Merge the data_main DataFrame with the vendors DataFrame on 'Primary Source Campaign'
data_merged = data_main.merge(vendors_data_req, on='Primary Source Campaign', how='left')
data_merged.tail()
# Out:
#                                Prospect ID Mobile Number    Phone Number  \
# 2746  044460b5-bcb9-4f2d-a264-516a891b3ed5    8851490344   91 8851490344
# 2747  547e7762-0448-489e-99cc-d5cec61f4af1    7509581691   91 7509581691
# 2748  d2b769c4-7997-469e-8d75-775039c21fcc    9818190875   91 9818190875
# 2749  9d6e7b6c-d45e-40d4-adb4-7195899a8c58    6232995266   91 6232995266
# 2750  4b10a131-1166-49a6-929d-12b4f9001532    8101146116   91 8101146116
#
#                           Email                   Primary Source Campaign  \
# 2746         kroy1204@gmail.com             Pravin_Khetan_YT_8_March_2024
# 2747       m456231798@gmail.com  7_Dreams_India_Official_YT1_18_June_2024
# 2748   cooldoonpiyush@gmail.com               Shubh_Kadam_TG_19_June_2024
# 2749        hg5526239@gmail.com              Shrija_Saha_YT1_13_June_2024
# 2750  karismapramanik@gmail.com            Market_Support_YT1_3_June_2024
#
#              eKYC Stage Code  Total Payment Amount              Created On  \
# 2746           e15_Activated                2415.0  2024-07-01 12:35:55 AM
# 2747  e14_Activation_Process                1207.0  2024-07-01 05:29:52 PM
# 2748           e15_Activated                  99.0  2024-07-01 01:02:09 PM
# 2749           e15_Activated                1207.0  2024-07-01 02:02:28 PM
# 2750           e15_Activated                   0.0  2024-07-01 12:14:54 PM
#
#                   Bitly Link      agency
# 2746                     NaN         NaN
# 2747  https://bit.ly/4b71j7P  Raghuvansh
# 2748                     NaN         NaN
# 2749  https://bit.ly/3VHEuTV  Raghuvansh
# 2750  https://bit.ly/3RcX57L    Cashjosh

# %%
data_merged.shape[0]
# Out:
# 2751

# %%
data_merged.isna().sum()
# Out:
# Prospect ID                   0
# Mobile Number                 0
# Phone Number                  0
# Email                       984
# Primary Source Campaign       0
# eKYC Stage Code               0
# Total Payment Amount       1445
# Created On                    0
# Bitly Link                  395
# agency                      395
# dtype: int64

# %% [markdown]
# ## **Task 4 -Creating a new column Lead Stage**

# %%
# 
# a new column called lead stage 
# if eKYC has e12 OR e14 OR e15 then account opended AND Total Payment Amount is greater 100 then  
# else in proccess

# %%
data_merged['Total Payment Amount'].fillna(0, inplace=True)
data_merged.head()
# Out:
#                             Prospect ID Mobile Number    Phone Number  \
# 0  367ad3f4-f682-4b5b-bd59-271b060f3cdf    8217253062   91 8217253062
# 1  d5d6a80b-31d3-4bdb-aa29-53bc5562f940    8191999195   91 8191999195
# 2  b186afee-9c26-4d9d-bacd-5ba0c5d63321    7037092729   91 7037092729
# 3  a6f2ccf1-742f-43b1-b46f-b2dbf22233b4    9927263738   91 9927263738
# 4  5fa98042-50b8-4bfd-8c50-0f77c87b31a7    7617651326   91 7617651326
#
#                        Email  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3    khushimbd2019@gmail.com
# 4  yogeshpal121199@gmail.com
#
#                              Primary Source Campaign         eKYC Stage Code  \
# 0                  Vivek_Singh_Rana_YT1_12_June_2024               e1_Mobile
# 1                   Snehilop_Gaming_YT1_15_June_2024               e1_Mobile
# 2  Money_Talks_With_Payal_YT1_1_July_2024_e348b33...               e1_Mobile
# 3                        Rs_Fintech_YT1_13_June_2024               e12_eSign
# 4                   Snehilop_Gaming_YT1_15_June_2024  e14_Activation_Process
#
#    Total Payment Amount              Created On              Bitly Link  \
# 0                   0.0  2024-07-07 12:31:05 PM  https://bit.ly/3VopUz3
# 1                   0.0  2024-07-07 12:40:25 PM  https://bit.ly/3XpzUuy
# 2                   0.0  2024-07-08 04:02:06 PM                     NaN
# 3                   0.0  2024-07-06 10:37:02 PM  https://bit.ly/3VrgCSW
# 4                1207.0  2024-07-07 11:05:14 AM  https://bit.ly/3XpzUuy
#
#        agency
# 0          BS
# 1          BS
# 2         NaN
# 3  Raghuvansh
# 4          BS

# %%
data_merged.insert(5, 'Lead Stage', None)
data_merged.head()
# Out:
#                             Prospect ID Mobile Number    Phone Number  \
# 0  367ad3f4-f682-4b5b-bd59-271b060f3cdf    8217253062   91 8217253062
# 1  d5d6a80b-31d3-4bdb-aa29-53bc5562f940    8191999195   91 8191999195
# 2  b186afee-9c26-4d9d-bacd-5ba0c5d63321    7037092729   91 7037092729
# 3  a6f2ccf1-742f-43b1-b46f-b2dbf22233b4    9927263738   91 9927263738
# 4  5fa98042-50b8-4bfd-8c50-0f77c87b31a7    7617651326   91 7617651326
#
#                        Email  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3    khushimbd2019@gmail.com
# 4  yogeshpal121199@gmail.com
#
#                              Primary Source Campaign Lead Stage  \
# 0                  Vivek_Singh_Rana_YT1_12_June_2024       None
# 1                   Snehilop_Gaming_YT1_15_June_2024       None
# 2  Money_Talks_With_Payal_YT1_1_July_2024_e348b33...       None
# 3                        Rs_Fintech_YT1_13_June_2024       None
# 4                   Snehilop_Gaming_YT1_15_June_2024       None
#
#           eKYC Stage Code  Total Payment Amount              Created On  \
# 0               e1_Mobile                   0.0  2024-07-07 12:31:05 PM
# 1               e1_Mobile                   0.0  2024-07-07 12:40:25 PM
# 2               e1_Mobile                   0.0  2024-07-08 04:02:06 PM
# 3               e12_eSign                   0.0  2024-07-06 10:37:02 PM
# 4  e14_Activation_Process                1207.0  2024-07-07 11:05:14 AM
#
#                Bitly Link      agency
# 0  https://bit.ly/3VopUz3          BS
# 1  https://bit.ly/3XpzUuy          BS
# 2                     NaN         NaN
# 3  https://bit.ly/3VrgCSW  Raghuvansh
# 4  https://bit.ly/3XpzUuy          BS

# %%
# Define the generate_lead_stage function
def generate_lead_stage(row):
    ekyc_stage_code = row['eKYC Stage Code']
    total_payment_amount = row['Total Payment Amount']
    
    if 'e12' in ekyc_stage_code or 'e14' in ekyc_stage_code or 'e15' in ekyc_stage_code:
        if total_payment_amount > 100:
            return '999-Account Opened'
        else:
            return 'L4-Account Opened'
    else:
        return 'L2-in process'

# %%
data_merged['Lead Stage'] = data_merged.apply(generate_lead_stage, axis=1)
data_merged.head()
# Out:
#                             Prospect ID Mobile Number    Phone Number  \
# 0  367ad3f4-f682-4b5b-bd59-271b060f3cdf    8217253062   91 8217253062
# 1  d5d6a80b-31d3-4bdb-aa29-53bc5562f940    8191999195   91 8191999195
# 2  b186afee-9c26-4d9d-bacd-5ba0c5d63321    7037092729   91 7037092729
# 3  a6f2ccf1-742f-43b1-b46f-b2dbf22233b4    9927263738   91 9927263738
# 4  5fa98042-50b8-4bfd-8c50-0f77c87b31a7    7617651326   91 7617651326
#
#                        Email  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3    khushimbd2019@gmail.com
# 4  yogeshpal121199@gmail.com
#
#                              Primary Source Campaign          Lead Stage  \
# 0                  Vivek_Singh_Rana_YT1_12_June_2024       L2-in process
# 1                   Snehilop_Gaming_YT1_15_June_2024       L2-in process
# 2  Money_Talks_With_Payal_YT1_1_July_2024_e348b33...       L2-in process
# 3                        Rs_Fintech_YT1_13_June_2024   L4-Account Opened
# 4                   Snehilop_Gaming_YT1_15_June_2024  999-Account Opened
#
#           eKYC Stage Code  Total Payment Amount              Created On  \
# 0               e1_Mobile                   0.0  2024-07-07 12:31:05 PM
# 1               e1_Mobile                   0.0  2024-07-07 12:40:25 PM
# 2               e1_Mobile                   0.0  2024-07-08 04:02:06 PM
# 3               e12_eSign                   0.0  2024-07-06 10:37:02 PM
# 4  e14_Activation_Process                1207.0  2024-07-07 11:05:14 AM
#
#                Bitly Link      agency
# 0  https://bit.ly/3VopUz3          BS
# 1  https://bit.ly/3XpzUuy          BS
# 2                     NaN         NaN
# 3  https://bit.ly/3VrgCSW  Raghuvansh
# 4  https://bit.ly/3XpzUuy          BS

# %%
print(data_merged.isna().sum())
print(data_merged.shape[0])
# Out:
# Prospect ID                  0
# Mobile Number                0
# Phone Number                 0
# Email                      984
# Primary Source Campaign      0
# Lead Stage                   0
# eKYC Stage Code              0
# Total Payment Amount         0
# Created On                   0
# Bitly Link                 395
# agency                     395
# dtype: int64
# 2751

# %%
data_merged.dropna(subset=['agency', 'Bitly Link'], inplace=True)
data_merged.head()
# Out:
#                             Prospect ID Mobile Number    Phone Number  \
# 0  367ad3f4-f682-4b5b-bd59-271b060f3cdf    8217253062   91 8217253062
# 1  d5d6a80b-31d3-4bdb-aa29-53bc5562f940    8191999195   91 8191999195
# 3  a6f2ccf1-742f-43b1-b46f-b2dbf22233b4    9927263738   91 9927263738
# 4  5fa98042-50b8-4bfd-8c50-0f77c87b31a7    7617651326   91 7617651326
# 5  df202edd-bc4d-403e-991a-af8c72ace075    9368632074   91 9368632074
#
#                        Email            Primary Source Campaign  \
# 0                        NaN  Vivek_Singh_Rana_YT1_12_June_2024
# 1                        NaN   Snehilop_Gaming_YT1_15_June_2024
# 3    khushimbd2019@gmail.com        Rs_Fintech_YT1_13_June_2024
# 4  yogeshpal121199@gmail.com   Snehilop_Gaming_YT1_15_June_2024
# 5                        NaN  Vivek_Singh_Rana_YT1_12_June_2024
#
#            Lead Stage         eKYC Stage Code  Total Payment Amount  \
# 0       L2-in process               e1_Mobile                   0.0
# 1       L2-in process               e1_Mobile                   0.0
# 3   L4-Account Opened               e12_eSign                   0.0
# 4  999-Account Opened  e14_Activation_Process                1207.0
# 5       L2-in process               e1_Mobile                   0.0
#
#                Created On              Bitly Link      agency
# 0  2024-07-07 12:31:05 PM  https://bit.ly/3VopUz3          BS
# 1  2024-07-07 12:40:25 PM  https://bit.ly/3XpzUuy          BS
# 3  2024-07-06 10:37:02 PM  https://bit.ly/3VrgCSW  Raghuvansh
# 4  2024-07-07 11:05:14 AM  https://bit.ly/3XpzUuy          BS
# 5  2024-07-07 12:46:05 PM  https://bit.ly/3VopUz3          BS

# %%
data_merged.shape[0]
# Out:
# 2356

# %% [markdown]
# ## **dropping unused columns**

# %%
data_merged.drop(columns=['Prospect ID', 'Phone Number', 'Email'], inplace=True)
data_merged.head()
# Out:
#   Mobile Number            Primary Source Campaign          Lead Stage  \
# 0    8217253062  Vivek_Singh_Rana_YT1_12_June_2024       L2-in process
# 1    8191999195   Snehilop_Gaming_YT1_15_June_2024       L2-in process
# 3    9927263738        Rs_Fintech_YT1_13_June_2024   L4-Account Opened
# 4    7617651326   Snehilop_Gaming_YT1_15_June_2024  999-Account Opened
# 5    9368632074  Vivek_Singh_Rana_YT1_12_June_2024       L2-in process
#
#           eKYC Stage Code  Total Payment Amount              Created On  \
# 0               e1_Mobile                   0.0  2024-07-07 12:31:05 PM
# 1               e1_Mobile                   0.0  2024-07-07 12:40:25 PM
# 3               e12_eSign                   0.0  2024-07-06 10:37:02 PM
# 4  e14_Activation_Process                1207.0  2024-07-07 11:05:14 AM
# 5               e1_Mobile                   0.0  2024-07-07 12:46:05 PM
#
#                Bitly Link      agency
# 0  https://bit.ly/3VopUz3          BS
# 1  https://bit.ly/3XpzUuy          BS
# 3  https://bit.ly/3VrgCSW  Raghuvansh
# 4  https://bit.ly/3XpzUuy          BS
# 5  https://bit.ly/3VopUz3          BS

# %% [markdown]
# ## **creating a pivot**

# %%
data_merged.columns = data_merged.columns.astype(str)
data_merged['Total Payment Amount'] = data_merged['Total Payment Amount'].astype('int64')
data_merged.dtypes
# Out:
# Mobile Number              object
# Primary Source Campaign    object
# Lead Stage                 object
# eKYC Stage Code            object
# Total Payment Amount        int64
# Created On                 object
# Bitly Link                 object
# agency                     object
# dtype: object

# %%
data_merged = data_merged.reset_index(drop=True)

# %%
data_merged_pivot = pd.pivot_table(data_merged, 
                                   index='Primary Source Campaign',
                                   columns='Lead Stage',
                                   values='Mobile Number',
                                   aggfunc='count',
                                   fill_value=0)
data_merged_pivot
# Out:
# Lead Stage                                999-Account Opened  L2-in process  \
# Primary Source Campaign
# 7_Dreams_India_Official_YT1_18_June_2024                  50             32
# Alok_Games_YT1_14_June_2024                                0              4
# Banking_Baba_YT1_8_June_2024                               3              1
# Bull_Earner_YT1_2_July_2024                                0             12
# CA_shitij_Gupta_YT1_6_June_2024                            4              1
# Charging_Point_Hindi_YT1_18_June_2024                      6              1
# Chaudhary_Tips_YT1_10_June_2024                            0              1
# Deekay_Financials_YT1_8_June_2024                          0              2
# Digital_Expert_YT1_13_June_2024                            0              8
# Digital_Expert_YT1_4_July_2024                             0              5
# Digital_Shashank_YT1_3_July_2024                           0              5
# Earning_Beast_YT1_3_July_2024                              0             91
# Expose_Buddy_YT1_3_July_2024                               0              4
# Loot_Earning_YT1_3_July_2024                               0             77
# Market_Support_YT1_11_June_2024                           42              7
# Market_Support_YT1_3_June_2024                             0              0
# Mission_Market_YT1_14_June_2024                           19              1
# Money_Matters_YT1_13_June_2024                             2              2
# Mr._Rishi_YT1_27_May_2024                                  1              0
# My_stock_World_YT1_18_June_2024                           96             26
# Ready_To_Invest_YT1_7_June_2024                           10              2
# Rs_Fintech_YT1_13_June_2024                                0             30
# Rs_Fintech_YT1_6_June_2024                                 2              0
# RupeeMonk_YT1_12_June_2024                                 0            124
# Saving_Fund_YT1_3_July_2024                                0             84
# Share_Market_Analysis_YT1_1_July_2024                      0              6
# Shashank_Yadav_YT1_4_July_2024                             0            104
# Shrija_Saha_YT1_13_June_2024                               7              0
# Sm_Investor_YT1_15_June_2024                               0            347
# Snehilop_Gaming_YT1_15_June_2024                         164             28
# Stock247_YT1_11_June_2024                                  0              1
# Stock247_YT1_2_July_2024                                   0              0
# Sunday_Nivesh_YT1_13_June_2024                             0             15
# The_Analyst_Deep_YT1_13_June_2024                          0              5
# The_mini_trader_YT1_12_June_2024                           2              3
# The_mini_trader_YT1_2_July_2024                            0             91
# Vivek_Singh_Rana_YT1_12_June_2024                          0            244
# Vivek_Singh_Rana_YT1_1_June_2024                           0              2
# aayush_SSM_YT1_6_June_2024                                15              6
#
# Lead Stage                                L4-Account Opened
# Primary Source Campaign
# 7_Dreams_India_Official_YT1_18_June_2024                  3
# Alok_Games_YT1_14_June_2024                               3
# Banking_Baba_YT1_8_June_2024                              0
# Bull_Earner_YT1_2_July_2024                              28
# CA_shitij_Gupta_YT1_6_June_2024                           0
# Charging_Point_Hindi_YT1_18_June_2024                     0
# Chaudhary_Tips_YT1_10_June_2024                           0
# Deekay_Financials_YT1_8_June_2024                         0
# Digital_Expert_YT1_13_June_2024                          13
# Digital_Expert_YT1_4_July_2024                            5
# Digital_Shashank_YT1_3_July_2024                          0
# Earning_Beast_YT1_3_July_2024                             0
# Expose_Buddy_YT1_3_July_2024                              2
# Loot_Earning_YT1_3_July_2024                              0
# Market_Support_YT1_11_June_2024                          17
# Market_Support_YT1_3_June_2024                            1
# Mission_Market_YT1_14_June_2024                           0
# Money_Matters_YT1_13_June_2024                            1
# Mr._Rishi_YT1_27_May_2024                                 0
# My_stock_World_YT1_18_June_2024                          54
# Ready_To_Invest_YT1_7_June_2024                           3
# Rs_Fintech_YT1_13_June_2024                              25
# Rs_Fintech_YT1_6_June_2024                                0
# RupeeMonk_YT1_12_June_2024                                0
# Saving_Fund_YT1_3_July_2024                               0
# Share_Market_Analysis_YT1_1_July_2024                    47
# Shashank_Yadav_YT1_4_July_2024                            0
# Shrija_Saha_YT1_13_June_2024                              1
# Sm_Investor_YT1_15_June_2024                              0
# Snehilop_Gaming_YT1_15_June_2024                         24
# Stock247_YT1_11_June_2024                                27
# Stock247_YT1_2_July_2024                                  5
# Sunday_Nivesh_YT1_13_June_2024                           87
# The_Analyst_Deep_YT1_13_June_2024                         0
# The_mini_trader_YT1_12_June_2024                          0
# The_mini_trader_YT1_2_July_2024                         215
# Vivek_Singh_Rana_YT1_12_June_2024                         0
# Vivek_Singh_Rana_YT1_1_June_2024                          0
# aayush_SSM_YT1_6_June_2024                                0

# %%
print(data_merged_pivot.shape[0])
print(data_merged['Primary Source Campaign'].nunique())
# Out:
# 39
# 39

# %%
sum_row = data_merged_pivot.sum()
sum_row.name = 'Total'
data_merged_pivot = pd.concat([data_merged_pivot, pd.DataFrame(sum_row).T])

# %%
data_merged_pivot = data_merged_pivot.reset_index()
data_merged_pivot.tail()
# Out:
# Lead Stage                              index  999-Account Opened  \
# 35            The_mini_trader_YT1_2_July_2024                   0
# 36          Vivek_Singh_Rana_YT1_12_June_2024                   0
# 37           Vivek_Singh_Rana_YT1_1_June_2024                   0
# 38                 aayush_SSM_YT1_6_June_2024                  15
# 39                                      Total                 423
#
# Lead Stage  L2-in process  L4-Account Opened
# 35                     91                215
# 36                    244                  0
# 37                      2                  0
# 38                      6                  0
# 39                   1372                561

# %%
# Rename the columns as needed
data_merged_pivot.columns.name = None
data_merged_pivot.columns = ['Primary Source Campaign', '999-Account Opened', 'L2-in process', 'L4-Account Opened']
data_merged_pivot.head()
# Out:
#                     Primary Source Campaign  999-Account Opened  \
# 0  7_Dreams_India_Official_YT1_18_June_2024                  50
# 1               Alok_Games_YT1_14_June_2024                   0
# 2              Banking_Baba_YT1_8_June_2024                   3
# 3               Bull_Earner_YT1_2_July_2024                   0
# 4           CA_shitij_Gupta_YT1_6_June_2024                   4
#
#    L2-in process  L4-Account Opened
# 0             32                  3
# 1              4                  3
# 2              1                  0
# 3             12                 28
# 4              1                  0

# %% [markdown]
# ## **merging the Bitly Link	with Pivot**

# %%
# Create a dictionary to map 'Primary Source Campaign' to 'Bitly Link'
campaign_to_bitly = data_merged.set_index('Primary Source Campaign')['Bitly Link'].to_dict()

# %%
# Add 'Bitly Link' column to data_merged_pivot by mapping
data_merged_pivot['Bitly Link'] = data_merged_pivot['Primary Source Campaign'].map(campaign_to_bitly)

# %%
data_merged_pivot.shape[0]
# Out:
# 40

# %%
data_merged_pivot
# Out:
#                      Primary Source Campaign  999-Account Opened  \
# 0   7_Dreams_India_Official_YT1_18_June_2024                  50
# 1                Alok_Games_YT1_14_June_2024                   0
# 2               Banking_Baba_YT1_8_June_2024                   3
# 3                Bull_Earner_YT1_2_July_2024                   0
# 4            CA_shitij_Gupta_YT1_6_June_2024                   4
# 5      Charging_Point_Hindi_YT1_18_June_2024                   6
# 6            Chaudhary_Tips_YT1_10_June_2024                   0
# 7          Deekay_Financials_YT1_8_June_2024                   0
# 8            Digital_Expert_YT1_13_June_2024                   0
# 9             Digital_Expert_YT1_4_July_2024                   0
# 10          Digital_Shashank_YT1_3_July_2024                   0
# 11             Earning_Beast_YT1_3_July_2024                   0
# 12              Expose_Buddy_YT1_3_July_2024                   0
# 13              Loot_Earning_YT1_3_July_2024                   0
# 14           Market_Support_YT1_11_June_2024                  42
# 15            Market_Support_YT1_3_June_2024                   0
# 16           Mission_Market_YT1_14_June_2024                  19
# 17            Money_Matters_YT1_13_June_2024                   2
# 18                 Mr._Rishi_YT1_27_May_2024                   1
# 19           My_stock_World_YT1_18_June_2024                  96
# 20           Ready_To_Invest_YT1_7_June_2024                  10
# 21               Rs_Fintech_YT1_13_June_2024                   0
# 22                Rs_Fintech_YT1_6_June_2024                   2
# 23                RupeeMonk_YT1_12_June_2024                   0
# 24               Saving_Fund_YT1_3_July_2024                   0
# 25     Share_Market_Analysis_YT1_1_July_2024                   0
# 26            Shashank_Yadav_YT1_4_July_2024                   0
# 27              Shrija_Saha_YT1_13_June_2024                   7
# 28              Sm_Investor_YT1_15_June_2024                   0
# 29          Snehilop_Gaming_YT1_15_June_2024                 164
# 30                 Stock247_YT1_11_June_2024                   0
# 31                  Stock247_YT1_2_July_2024                   0
# 32            Sunday_Nivesh_YT1_13_June_2024                   0
# 33         The_Analyst_Deep_YT1_13_June_2024                   0
# 34          The_mini_trader_YT1_12_June_2024                   2
# 35           The_mini_trader_YT1_2_July_2024                   0
# 36         Vivek_Singh_Rana_YT1_12_June_2024                   0
# 37          Vivek_Singh_Rana_YT1_1_June_2024                   0
# 38                aayush_SSM_YT1_6_June_2024                  15
# 39                                     Total                 423
#
#     L2-in process  L4-Account Opened              Bitly Link
# 0              32                  3  https://bit.ly/4b71j7P
# 1               4                  3  https://bit.ly/4bYYYwR
# 2               1                  0  https://bit.ly/4ce3Uh4
# 3              12                 28  https://bit.ly/4cGy3py
# 4               1                  0  https://bit.ly/4e9BbvT
# 5               1                  0  https://bit.ly/3z8evw1
# 6               1                  0  https://bit.ly/3x3kyRY
# 7               2                  0  https://bit.ly/3VDBZlC
# 8               8                 13  https://bit.ly/4chIS1g
# 9               5                  5  https://bit.ly/3RXdgpT
# 10              5                  0  https://bit.ly/45Pskf6
# 11             91                  0  https://bit.ly/3xAs6fg
# 12              4                  2  https://bit.ly/4d5Idk7
# 13             77                  0  https://bit.ly/4bxEcUj
# 14              7                 17  https://bit.ly/3RpGdur
# 15              0                  1  https://bit.ly/3RcX57L
# 16              1                  0  https://bit.ly/3z36rMY
# 17              2                  1  https://bit.ly/3RpvVu8
# 18              0                  0  https://bit.ly/4dV1G8d
# 19             26                 54  https://bit.ly/3zgzzjM
# 20              2                  3  https://bit.ly/3yQVG0i
# 21             30                 25  https://bit.ly/3VrgCSW
# 22              0                  0  https://bit.ly/4b09NxK
# 23            124                  0  https://bit.ly/4c0uyuk
# 24             84                  0  https://bit.ly/3RTNiDY
# 25              6                 47  https://bit.ly/3zu0JnB
# 26            104                  0  https://bit.ly/4d6PMXN
# 27              0                  1  https://bit.ly/3VHEuTV
# 28            347                  0  https://bit.ly/4esMzD6
# 29             28                 24  https://bit.ly/3XpzUuy
# 30              1                 27  https://bit.ly/3VB890W
# 31              0                  5  https://bit.ly/3RUnO9r
# 32             15                 87  https://bit.ly/3Vkru5f
# 33              5                  0  https://bit.ly/3Vr285s
# 34              3                  0  https://bit.ly/4bXYrLE
# 35             91                215  https://bit.ly/4coDGcx
# 36            244                  0  https://bit.ly/3VopUz3
# 37              2                  0  https://bit.ly/3wRxVEK
# 38              6                  0  https://bit.ly/4cbb0mA
# 39           1372                561                     NaN

# %% [markdown]
# ## **Coverting all results to EXCEL File**

# %%
with pd.ExcelWriter('C:\\Users\\hp\\Downloads\\Lead Report - 9th July output.xlsx', engine='xlsxwriter') as writer:
    data_merged.to_excel(writer, sheet_name='Data Cleaned', index=False)
    data_merged_pivot.to_excel(writer, sheet_name='Pivot', index=False)

# %% [markdown]
# ## **Creating Agency wise Everything**

# %%
agency_groups = data_merged.groupby('agency')
agency_dfs = {agency: group.drop(columns=['agency']) for agency, group in agency_groups}

# %%
list_of_agency = []
list_of_agency_df = []
for agency, df in agency_dfs.items():
    list_of_agency.append(agency)
    list_of_agency_df.append(df)

print(list_of_agency)
#print(list_of_agency_df)
# Out:
# ['BS', 'Cashjosh', 'Dheerendra raj', 'Fasto', 'MediaXPedia', 'Pahi-j', 'Raghuvansh', 'addensure', 'affilienet']

# %%
list_of_agency_df[0]
# Out:
#      Mobile Number            Primary Source Campaign          Lead Stage  \
# 0       8217253062  Vivek_Singh_Rana_YT1_12_June_2024       L2-in process
# 1       8191999195   Snehilop_Gaming_YT1_15_June_2024       L2-in process
# 3       7617651326   Snehilop_Gaming_YT1_15_June_2024  999-Account Opened
# 4       9368632074  Vivek_Singh_Rana_YT1_12_June_2024       L2-in process
# 5       7757871720       Sm_Investor_YT1_15_June_2024       L2-in process
# ...            ...                                ...                 ...
# 2314    8218506120    My_stock_World_YT1_18_June_2024   L4-Account Opened
# 2315    7861886560        Alok_Games_YT1_14_June_2024   L4-Account Opened
# 2319    7248188743   Snehilop_Gaming_YT1_15_June_2024  999-Account Opened
# 2324    9582523601   Snehilop_Gaming_YT1_15_June_2024  999-Account Opened
# 2329    8813001802    My_stock_World_YT1_18_June_2024   L4-Account Opened
#
#              eKYC Stage Code  Total Payment Amount              Created On  \
# 0                  e1_Mobile                     0  2024-07-07 12:31:05 PM
# 1                  e1_Mobile                     0  2024-07-07 12:40:25 PM
# 3     e14_Activation_Process                  1207  2024-07-07 11:05:14 AM
# 4                  e1_Mobile                     0  2024-07-07 12:46:05 PM
# 5                  e1_Mobile                     0  2024-07-08 12:14:39 PM
# ...                      ...                   ...                     ...
# 2314               e12_eSign                     0  2024-07-03 02:08:26 PM
# 2315  e14_Activation_Process                     0  2024-07-03 12:08:34 PM
# 2319  e14_Activation_Process                  1207  2024-07-03 07:04:50 PM
# 2324  e14_Activation_Process                  1207  2024-07-03 03:06:04 PM
# 2329  e14_Activation_Process                     0  2024-07-03 10:29:08 AM
#
#                   Bitly Link
# 0     https://bit.ly/3VopUz3
# 1     https://bit.ly/3XpzUuy
# 3     https://bit.ly/3XpzUuy
# 4     https://bit.ly/3VopUz3
# 5     https://bit.ly/4esMzD6
# ...                      ...
# 2314  https://bit.ly/3zgzzjM
# 2315  https://bit.ly/4bYYYwR
# 2319  https://bit.ly/3XpzUuy
# 2324  https://bit.ly/3XpzUuy
# 2329  https://bit.ly/3zgzzjM
#
# [1655 rows x 7 columns]

# %%
list_of_agency_df[0].columns
# Out:
# Index(['Mobile Number', 'Primary Source Campaign', 'Lead Stage',
#        'eKYC Stage Code', 'Total Payment Amount', 'Created On', 'Bitly Link'],
#       dtype='object')

# %%
pivoted_df = []
for each_df in list_of_agency_df:
    each_df_pivot = pd.pivot_table(each_df, index='Primary Source Campaign', columns='Lead Stage', values='Mobile Number', aggfunc='count', fill_value=0)

    # adding a row of TOTAL
    sum_row = each_df_pivot.sum()
    sum_row.name = 'TOTAL'
    each_df_pivot = pd.concat([each_df_pivot, pd.DataFrame(sum_row).T])

    # Reset the index to make 'Primary Source Campaign' a regular column
    each_df_pivot = each_df_pivot.reset_index()

    # Ensure all desired columns are present
    required_columns = ['999-Account Opened', 'L2-in process', 'L4-Account Opened']
    for col in required_columns:
        if col not in each_df_pivot.columns:
            each_df_pivot[col] = 0
    
    # Reorder the columns
    # each_df_pivot = each_df_pivot[['Primary Source Campaign'] + required_columns]

    # renaming pivot column index to Primary Source Campaign
    each_df_pivot.rename(columns={'index':'Primary Source Campaign'}, inplace=True)
    
    # merging Bitly Links to it ---- # Create a dictionary to map 'Primary Source Campaign' to 'Bitly Link'
    campaign_to_bitly = each_df.set_index('Primary Source Campaign')['Bitly Link'].to_dict()

    # Add 'Bitly Link' column to data_merged_pivot by mapping
    each_df_pivot['Bitly Link'] = each_df_pivot['Primary Source Campaign'].map(campaign_to_bitly)
    
    pivoted_df.append(each_df_pivot)

agency_pivotdf_dict = agency_dfs.copy()
agency_pivotdf_dict.update(dict(zip(agency_dfs.keys(), pivoted_df)))

# %%
pivoted_df[0]
# Out:
# Lead Stage                Primary Source Campaign  999-Account Opened  \
# 0                     Alok_Games_YT1_14_June_2024                   0
# 1                     Bull_Earner_YT1_2_July_2024                   0
# 2                 My_stock_World_YT1_18_June_2024                  96
# 3                      RupeeMonk_YT1_12_June_2024                   0
# 4           Share_Market_Analysis_YT1_1_July_2024                   0
# 5                    Sm_Investor_YT1_15_June_2024                   0
# 6                Snehilop_Gaming_YT1_15_June_2024                 164
# 7                       Stock247_YT1_11_June_2024                   0
# 8                        Stock247_YT1_2_July_2024                   0
# 9                  Sunday_Nivesh_YT1_13_June_2024                   0
# 10              The_Analyst_Deep_YT1_13_June_2024                   0
# 11                The_mini_trader_YT1_2_July_2024                   0
# 12              Vivek_Singh_Rana_YT1_12_June_2024                   0
# 13               Vivek_Singh_Rana_YT1_1_June_2024                   0
# 14                                          TOTAL                 260
#
# Lead Stage  L2-in process  L4-Account Opened              Bitly Link
# 0                       4                  3  https://bit.ly/4bYYYwR
# 1                      12                 28  https://bit.ly/4cGy3py
# 2                      26                 54  https://bit.ly/3zgzzjM
# 3                     124                  0  https://bit.ly/4c0uyuk
# 4                       6                 47  https://bit.ly/3zu0JnB
# 5                     347                  0  https://bit.ly/4esMzD6
# 6                      28                 24  https://bit.ly/3XpzUuy
# 7                       1                 27  https://bit.ly/3VB890W
# 8                       0                  5  https://bit.ly/3RUnO9r
# 9                      15                 87  https://bit.ly/3Vkru5f
# 10                      5                  0  https://bit.ly/3Vr285s
# 11                     91                215  https://bit.ly/4coDGcx
# 12                    244                  0  https://bit.ly/3VopUz3
# 13                      2                  0  https://bit.ly/3wRxVEK
# 14                    905                490                     NaN

# %%
#def craete_excel(dict):
with pd.ExcelWriter('excel files//output.xlsx', engine='xlsxwriter') as writer:
    for key, value in agency_pivotdf_dict.items():
        value.to_excel(writer, sheet_name=str(key), index=False)

# %%
pd.pivot_table(list_of_agency_df[0], index='Primary Source Campaign', columns='Lead Stage', values='Mobile Number', aggfunc='count', fill_value=0)

# %%
agency_dfs.keys()
