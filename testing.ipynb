# %% [markdown]
# # **Creating Automated Vendor Report Creation**

# %% [markdown]
# ## **importing packages**

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('Lead Report - 4th July.csv')
data.shape[0]
# Out:
# 333

# %%
#data.columns.to_list()

# %%
data_main = data[['Prospect ID', 'Mobile Number','Phone Number', 'Email', 'Primary Source Campaign', 'eKYC Stage Code', 'Total Payment Amount', 'Created On']]
data_main.head()
# Out:
#                             Prospect ID  Mobile Number    Phone Number  \
# 0  94ac0a7c-42d3-4c8b-bcd5-7470801a4d13     6290470684   91 6290470684
# 1  c7f84b50-73e5-4448-8e3a-1dde4ca75c28     7750035479   91 7750035479
# 2  a53066b8-7f14-4175-baf0-6b6608dab1d0     9012564044   91 9012564044
# 3  f0945c8f-1575-4e1f-84f0-01d9379d4151     7797203221   91 7797203221
# 4  f478e107-58f9-4de4-a52a-047d1879c5f1     9777667419   91 9777667419
#
#                       Email           Primary Source Campaign  \
# 0   psen2000gupta@gmail.com   The_mini_trader_YT1_2_July_2024
# 1  sritamsahoo580@gmail.com       Bull_Earner_YT1_2_July_2024
# 2   amir007870011@gmail.com  Snehilop_Gaming_YT1_15_June_2024
# 3                       NaN   The_mini_trader_YT1_2_July_2024
# 4                       NaN       Bull_Earner_YT1_2_July_2024
#
#           eKYC Stage Code  Total Payment Amount              Created On
# 0                e2_Email                   NaN  2024-07-04 09:41:48 AM
# 1        e6_Onscreen_Sign                   0.0  2024-07-04 09:39:44 AM
# 2  e14_Activation_Process                1207.0  2024-07-04 09:22:23 AM
# 3               e1_Mobile                   NaN  2024-07-03 08:49:18 PM
# 4               e1_Mobile                   NaN  2024-07-04 09:37:57 AM

# %%
data_main.columns.to_list()
# Out:
# ['Prospect ID',
#  'Mobile Number',
#  'Phone Number',
#  'Email',
#  'Primary Source Campaign',
#  'eKYC Stage Code',
#  'Total Payment Amount',
#  'Created On']

# %% [markdown]
# ## **Task 1 -Fill Mob No from Phone Number where Mob No is empty**

# %%
data_main.isnull().sum()
# Out:
# Prospect ID                 0
# Mobile Number               0
# Phone Number                0
# Email                      36
# Primary Source Campaign     0
# eKYC Stage Code             0
# Total Payment Amount       86
# Created On                  0
# dtype: int64

# %%
# Function to extract the last 10 digits of the phone number
def extract_last_10_digits(phone):
    return str(phone)[-10:]

# %%
# Fill the null values in 'Mobile Number' with the last 10 digits of 'Phone Number'
data_main['Mobile Number'] = data_main.apply(
    lambda row: extract_last_10_digits(row['Phone Number']) if pd.isnull(row['Mobile Number']) or row['Mobile Number'] in ['None', 'nan'] else row['Mobile Number'],
    axis=1)

# Convert 'Mobile Number' to integer to remove any .0, then back to string
data_main['Mobile Number'] = data_main['Mobile Number'].apply(lambda x: str(int(float(x))))

# %%
data_main.head()
# Out:
#                             Prospect ID Mobile Number    Phone Number  \
# 0  94ac0a7c-42d3-4c8b-bcd5-7470801a4d13    6290470684   91 6290470684
# 1  c7f84b50-73e5-4448-8e3a-1dde4ca75c28    7750035479   91 7750035479
# 2  a53066b8-7f14-4175-baf0-6b6608dab1d0    9012564044   91 9012564044
# 3  f0945c8f-1575-4e1f-84f0-01d9379d4151    7797203221   91 7797203221
# 4  f478e107-58f9-4de4-a52a-047d1879c5f1    9777667419   91 9777667419
#
#                       Email           Primary Source Campaign  \
# 0   psen2000gupta@gmail.com   The_mini_trader_YT1_2_July_2024
# 1  sritamsahoo580@gmail.com       Bull_Earner_YT1_2_July_2024
# 2   amir007870011@gmail.com  Snehilop_Gaming_YT1_15_June_2024
# 3                       NaN   The_mini_trader_YT1_2_July_2024
# 4                       NaN       Bull_Earner_YT1_2_July_2024
#
#           eKYC Stage Code  Total Payment Amount              Created On
# 0                e2_Email                   NaN  2024-07-04 09:41:48 AM
# 1        e6_Onscreen_Sign                   0.0  2024-07-04 09:39:44 AM
# 2  e14_Activation_Process                1207.0  2024-07-04 09:22:23 AM
# 3               e1_Mobile                   NaN  2024-07-03 08:49:18 PM
# 4               e1_Mobile                   NaN  2024-07-04 09:37:57 AM

# %% [markdown]
# ## **Task 2 - Fill 'e2_Email' in eKYC Stage Code colunm**

# %%
data_main["eKYC Stage Code"] = data_main['eKYC Stage Code'].fillna('e2_Email')

# %%
data_main['eKYC Stage Code'].isnull().sum()
# Out:
# 0

# %%
data_main.head()
# Out:
#                             Prospect ID Mobile Number    Phone Number  \
# 0  94ac0a7c-42d3-4c8b-bcd5-7470801a4d13    6290470684   91 6290470684
# 1  c7f84b50-73e5-4448-8e3a-1dde4ca75c28    7750035479   91 7750035479
# 2  a53066b8-7f14-4175-baf0-6b6608dab1d0    9012564044   91 9012564044
# 3  f0945c8f-1575-4e1f-84f0-01d9379d4151    7797203221   91 7797203221
# 4  f478e107-58f9-4de4-a52a-047d1879c5f1    9777667419   91 9777667419
#
#                       Email           Primary Source Campaign  \
# 0   psen2000gupta@gmail.com   The_mini_trader_YT1_2_July_2024
# 1  sritamsahoo580@gmail.com       Bull_Earner_YT1_2_July_2024
# 2   amir007870011@gmail.com  Snehilop_Gaming_YT1_15_June_2024
# 3                       NaN   The_mini_trader_YT1_2_July_2024
# 4                       NaN       Bull_Earner_YT1_2_July_2024
#
#           eKYC Stage Code  Total Payment Amount              Created On
# 0                e2_Email                   NaN  2024-07-04 09:41:48 AM
# 1        e6_Onscreen_Sign                   0.0  2024-07-04 09:39:44 AM
# 2  e14_Activation_Process                1207.0  2024-07-04 09:22:23 AM
# 3               e1_Mobile                   NaN  2024-07-03 08:49:18 PM
# 4               e1_Mobile                   NaN  2024-07-04 09:37:57 AM

# %% [markdown]
# ## **Task 3 - Adding Vendors to the data from  vendors sheet using VLOOKUP()**

# %%
csv_url = 'https://docs.google.com/spreadsheets/d/1osDdsySYQdoBZlguvbb_UCZt2wfRbQvhSj8B2qa_RgU/export?format=csv'

vendors_data = pd.read_csv(csv_url, header=None)
# Set the first row as the header
vendors_data.columns = vendors_data.iloc[1]
vendors_data = vendors_data.drop([0, 1]).reset_index(drop=True)
vendors_data.head()
# Out:
# 1 Video Month                         Channel  \
# 0      Oct 23                       Trade2Day
# 1      Oct 23           Investment with Tarun
# 2      Oct 23  Stock Market का Badshah (SMkB)
# 3      Oct 23                  Knowledge Jazz
# 4     July 23                             NaN
#
# 1                                        Video Link     CTC  \
# 0                      https://youtu.be/_akShxeeUXM  30,000
# 1       https://youtu.be/wuAg1NtzRIo?feature=shared  40,000
# 2                      https://youtu.be/WoCGzwg6Jwg  20,000
# 3  https://youtu.be/U_T-gllIkww?si=PLyJ7PxUpWZHD2de  65,000
# 4                                               NaN     NaN
#
# 1 Expected Lead counts as per CTC  \
# 0                               7
# 1                               9
# 2                               4
# 3                              14
# 4                               0
#
# 1                                            YT Link  \
# 0  https://www.mstock.com/sem-landing/zero-broker...
# 1  https://www.mstock.com/sem-landing/zero-broker...
# 2  https://www.mstock.com/sem-landing/zero-broker...
# 3  https://www.mstock.com/sem-landing/zero-broker...
# 4                                                NaN
#
# 1                                        TG/YT1 Link  \
# 0  https://www.mstock.com/sem-landing/zero-broker...
# 1  https://www.mstock.com/sem-landing/zero-broker...
# 2  https://www.mstock.com/sem-landing/zero-broker...
# 3  https://www.mstock.com/sem-landing/zero-broker...
# 4                                                NaN
#
# 1                             NaN            TG/YT1 Bitly  \
# 0                       Trade2Day  https://bit.ly/3ruhw6t
# 1           Investment with Tarun  https://bit.ly/45gSFkc
# 2  Stock Market का Badshah (SMkB)  https://bit.ly/3RKfr0U
# 3                  Knowledge Jazz  https://bit.ly/46xKLnE
# 4                             NaN  https://bit.ly/3ZH1FOs
#
# 1                                      campaign  ...          Agency  Status  \
# 0                     Trade2Day_TG_03rd_October  ...             MRN  Paused
# 1    Investment_with_Tarun_TG_03rd_October_2023  ...             MRN  Paused
# 2  Stock_Market_ka_Badshah_TG_03rd_October_2023  ...             UTM  Paused
# 3           Knowledge_Jazz_TG_03rd_October_2023  ...             UTM  Paused
# 4                trade_swings_TG_15th_july_2023  ...  BS Enterprises  Paused
#
# 1 TG Leads YT Leads Inf Leads     CPC Old link Old Bitly old campaign name  \
# 0      NaN      NaN       NaN  30,000      NaN       NaN               NaN
# 1      NaN      NaN       NaN  40,000      NaN       NaN               NaN
# 2      NaN      NaN       NaN  20,000      NaN       NaN               NaN
# 3       29      NaN       NaN   2,241      NaN       NaN               NaN
# 4      NaN      NaN       NaN     NaN      NaN       NaN               NaN
#
# 1  NaN
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN
#
# [5 rows x 21 columns]

# %%
vendors_data_req = vendors_data[['TG/YT1 Bitly','campaign', 'Agency']]
vendors_data_req.columns= ['Bitly Link','Primary Source Campaign','agency']
vendors_data_req.head()
# Out:
#                Bitly Link                       Primary Source Campaign  \
# 0  https://bit.ly/3ruhw6t                     Trade2Day_TG_03rd_October
# 1  https://bit.ly/45gSFkc    Investment_with_Tarun_TG_03rd_October_2023
# 2  https://bit.ly/3RKfr0U  Stock_Market_ka_Badshah_TG_03rd_October_2023
# 3  https://bit.ly/46xKLnE           Knowledge_Jazz_TG_03rd_October_2023
# 4  https://bit.ly/3ZH1FOs                trade_swings_TG_15th_july_2023
#
#            agency
# 0             MRN
# 1             MRN
# 2             UTM
# 3             UTM
# 4  BS Enterprises

# %%
print(vendors_data_req.isna().sum())
print(vendors_data_req.shape[0])
# Out:
# Bitly Link                 361
# Primary Source Campaign    362
# agency                     541
# dtype: int64
# 1143

# %%
vendors_data_req.dropna(how='any', inplace=True)
print(vendors_data_req.isna().sum())
print(vendors_data_req.shape[0])
# Out:
# Bitly Link                 0
# Primary Source Campaign    0
# agency                     0
# dtype: int64
# 601

# %%
# Merge the data_main DataFrame with the vendors DataFrame on 'Primary Source Campaign'
data_merged = data_main.merge(vendors_data_req, on='Primary Source Campaign', how='left')
data_merged.tail()
# Out:
#                               Prospect ID Mobile Number    Phone Number  \
# 328  d2b769c4-7997-469e-8d75-775039c21fcc    9818190875   91 9818190875
# 329  9d6e7b6c-d45e-40d4-adb4-7195899a8c58    6232995266   91 6232995266
# 330  4b10a131-1166-49a6-929d-12b4f9001532    8101146116   91 8101146116
# 331  4b0b920b-27da-472c-85eb-81b982b8cb28    8120361079   91 8120361079
# 332  ef382148-0d55-4de4-82a9-4f73f733d479    9762222286   91 9762222286
#
#                          Email                   Primary Source Campaign  \
# 328   cooldoonpiyush@gmail.com               Shubh_Kadam_TG_19_June_2024
# 329        hg5526239@gmail.com              Shrija_Saha_YT1_13_June_2024
# 330  karismapramanik@gmail.com            Market_Support_YT1_3_June_2024
# 331                        NaN  7_Dreams_India_Official_YT1_18_June_2024
# 332                        NaN          Vivek_Singh_Rana_YT1_1_June_2024
#
#     eKYC Stage Code  Total Payment Amount              Created On  \
# 328   e15_Activated                  99.0  2024-07-01 01:02:09 PM
# 329   e15_Activated                1207.0  2024-07-01 02:02:28 PM
# 330   e15_Activated                   0.0  2024-07-01 12:14:54 PM
# 331       e1_Mobile                   NaN  2024-07-01 03:16:12 PM
# 332       e1_Mobile                   NaN  2024-07-01 12:02:02 AM
#
#                  Bitly Link      agency
# 328                     NaN         NaN
# 329  https://bit.ly/3VHEuTV  Raghuvansh
# 330  https://bit.ly/3RcX57L    Cashjosh
# 331  https://bit.ly/4b71j7P  Raghuvansh
# 332  https://bit.ly/3wRxVEK          BS

# %%
data_merged.shape[0]
# Out:
# 333

# %%
data_merged.isna().sum()
# Out:
# Prospect ID                  0
# Mobile Number                0
# Phone Number                 0
# Email                       36
# Primary Source Campaign      0
# eKYC Stage Code              0
# Total Payment Amount        86
# Created On                   0
# Bitly Link                 102
# agency                     102
# dtype: int64

# %% [markdown]
# ## **Task 4 -Creating a new column Lead Stage**

# %%
# 
# a new column called lead stage 
# if eKYC has e12 OR e14 OR e15 then account opended AND Total Payment Amount is greater 100 then  
# else in proccess

# %%
data_merged['Total Payment Amount'].fillna(0, inplace=True)
data_merged.head()
# Out:
#                             Prospect ID Mobile Number    Phone Number  \
# 0  94ac0a7c-42d3-4c8b-bcd5-7470801a4d13    6290470684   91 6290470684
# 1  c7f84b50-73e5-4448-8e3a-1dde4ca75c28    7750035479   91 7750035479
# 2  a53066b8-7f14-4175-baf0-6b6608dab1d0    9012564044   91 9012564044
# 3  f0945c8f-1575-4e1f-84f0-01d9379d4151    7797203221   91 7797203221
# 4  f478e107-58f9-4de4-a52a-047d1879c5f1    9777667419   91 9777667419
#
#                       Email           Primary Source Campaign  \
# 0   psen2000gupta@gmail.com   The_mini_trader_YT1_2_July_2024
# 1  sritamsahoo580@gmail.com       Bull_Earner_YT1_2_July_2024
# 2   amir007870011@gmail.com  Snehilop_Gaming_YT1_15_June_2024
# 3                       NaN   The_mini_trader_YT1_2_July_2024
# 4                       NaN       Bull_Earner_YT1_2_July_2024
#
#           eKYC Stage Code  Total Payment Amount              Created On  \
# 0                e2_Email                   0.0  2024-07-04 09:41:48 AM
# 1        e6_Onscreen_Sign                   0.0  2024-07-04 09:39:44 AM
# 2  e14_Activation_Process                1207.0  2024-07-04 09:22:23 AM
# 3               e1_Mobile                   0.0  2024-07-03 08:49:18 PM
# 4               e1_Mobile                   0.0  2024-07-04 09:37:57 AM
#
#                Bitly Link agency
# 0  https://bit.ly/4coDGcx     BS
# 1  https://bit.ly/4cGy3py     BS
# 2  https://bit.ly/3XpzUuy     BS
# 3  https://bit.ly/4coDGcx     BS
# 4  https://bit.ly/4cGy3py     BS

# %%
data_merged.insert(5, 'Lead Stage', None)
data_merged.head()
# Out:
#                             Prospect ID Mobile Number    Phone Number  \
# 0  94ac0a7c-42d3-4c8b-bcd5-7470801a4d13    6290470684   91 6290470684
# 1  c7f84b50-73e5-4448-8e3a-1dde4ca75c28    7750035479   91 7750035479
# 2  a53066b8-7f14-4175-baf0-6b6608dab1d0    9012564044   91 9012564044
# 3  f0945c8f-1575-4e1f-84f0-01d9379d4151    7797203221   91 7797203221
# 4  f478e107-58f9-4de4-a52a-047d1879c5f1    9777667419   91 9777667419
#
#                       Email           Primary Source Campaign Lead Stage  \
# 0   psen2000gupta@gmail.com   The_mini_trader_YT1_2_July_2024       None
# 1  sritamsahoo580@gmail.com       Bull_Earner_YT1_2_July_2024       None
# 2   amir007870011@gmail.com  Snehilop_Gaming_YT1_15_June_2024       None
# 3                       NaN   The_mini_trader_YT1_2_July_2024       None
# 4                       NaN       Bull_Earner_YT1_2_July_2024       None
#
#           eKYC Stage Code  Total Payment Amount              Created On  \
# 0                e2_Email                   0.0  2024-07-04 09:41:48 AM
# 1        e6_Onscreen_Sign                   0.0  2024-07-04 09:39:44 AM
# 2  e14_Activation_Process                1207.0  2024-07-04 09:22:23 AM
# 3               e1_Mobile                   0.0  2024-07-03 08:49:18 PM
# 4               e1_Mobile                   0.0  2024-07-04 09:37:57 AM
#
#                Bitly Link agency
# 0  https://bit.ly/4coDGcx     BS
# 1  https://bit.ly/4cGy3py     BS
# 2  https://bit.ly/3XpzUuy     BS
# 3  https://bit.ly/4coDGcx     BS
# 4  https://bit.ly/4cGy3py     BS

# %%
# Define the generate_lead_stage function
def generate_lead_stage(row):
    ekyc_stage_code = row['eKYC Stage Code']
    total_payment_amount = row['Total Payment Amount']
    
    if 'e12' in ekyc_stage_code or 'e14' in ekyc_stage_code or 'e15' in ekyc_stage_code:
        if total_payment_amount > 100:
            return '999-Account Opened'
        else:
            return 'L4-Account Opened'
    else:
        return 'L2-in process'

# %%
data_merged['Lead Stage'] = data_merged.apply(generate_lead_stage, axis=1)
data_merged.head()
# Out:
#                             Prospect ID Mobile Number    Phone Number  \
# 0  94ac0a7c-42d3-4c8b-bcd5-7470801a4d13    6290470684   91 6290470684
# 1  c7f84b50-73e5-4448-8e3a-1dde4ca75c28    7750035479   91 7750035479
# 2  a53066b8-7f14-4175-baf0-6b6608dab1d0    9012564044   91 9012564044
# 3  f0945c8f-1575-4e1f-84f0-01d9379d4151    7797203221   91 7797203221
# 4  f478e107-58f9-4de4-a52a-047d1879c5f1    9777667419   91 9777667419
#
#                       Email           Primary Source Campaign  \
# 0   psen2000gupta@gmail.com   The_mini_trader_YT1_2_July_2024
# 1  sritamsahoo580@gmail.com       Bull_Earner_YT1_2_July_2024
# 2   amir007870011@gmail.com  Snehilop_Gaming_YT1_15_June_2024
# 3                       NaN   The_mini_trader_YT1_2_July_2024
# 4                       NaN       Bull_Earner_YT1_2_July_2024
#
#            Lead Stage         eKYC Stage Code  Total Payment Amount  \
# 0       L2-in process                e2_Email                   0.0
# 1       L2-in process        e6_Onscreen_Sign                   0.0
# 2  999-Account Opened  e14_Activation_Process                1207.0
# 3       L2-in process               e1_Mobile                   0.0
# 4       L2-in process               e1_Mobile                   0.0
#
#                Created On              Bitly Link agency
# 0  2024-07-04 09:41:48 AM  https://bit.ly/4coDGcx     BS
# 1  2024-07-04 09:39:44 AM  https://bit.ly/4cGy3py     BS
# 2  2024-07-04 09:22:23 AM  https://bit.ly/3XpzUuy     BS
# 3  2024-07-03 08:49:18 PM  https://bit.ly/4coDGcx     BS
# 4  2024-07-04 09:37:57 AM  https://bit.ly/4cGy3py     BS

# %%
data_merged.isna().sum()
data_merged.shape[0]
# Out:
# 333

# %%
data_merged.dropna(subset=['agency', 'Bitly Link'], inplace=True)
data_merged.head()
# Out:
#                             Prospect ID Mobile Number    Phone Number  \
# 0  94ac0a7c-42d3-4c8b-bcd5-7470801a4d13    6290470684   91 6290470684
# 1  c7f84b50-73e5-4448-8e3a-1dde4ca75c28    7750035479   91 7750035479
# 2  a53066b8-7f14-4175-baf0-6b6608dab1d0    9012564044   91 9012564044
# 3  f0945c8f-1575-4e1f-84f0-01d9379d4151    7797203221   91 7797203221
# 4  f478e107-58f9-4de4-a52a-047d1879c5f1    9777667419   91 9777667419
#
#                       Email           Primary Source Campaign  \
# 0   psen2000gupta@gmail.com   The_mini_trader_YT1_2_July_2024
# 1  sritamsahoo580@gmail.com       Bull_Earner_YT1_2_July_2024
# 2   amir007870011@gmail.com  Snehilop_Gaming_YT1_15_June_2024
# 3                       NaN   The_mini_trader_YT1_2_July_2024
# 4                       NaN       Bull_Earner_YT1_2_July_2024
#
#            Lead Stage         eKYC Stage Code  Total Payment Amount  \
# 0       L2-in process                e2_Email                   0.0
# 1       L2-in process        e6_Onscreen_Sign                   0.0
# 2  999-Account Opened  e14_Activation_Process                1207.0
# 3       L2-in process               e1_Mobile                   0.0
# 4       L2-in process               e1_Mobile                   0.0
#
#                Created On              Bitly Link agency
# 0  2024-07-04 09:41:48 AM  https://bit.ly/4coDGcx     BS
# 1  2024-07-04 09:39:44 AM  https://bit.ly/4cGy3py     BS
# 2  2024-07-04 09:22:23 AM  https://bit.ly/3XpzUuy     BS
# 3  2024-07-03 08:49:18 PM  https://bit.ly/4coDGcx     BS
# 4  2024-07-04 09:37:57 AM  https://bit.ly/4cGy3py     BS

# %%
data_merged.shape[0]
# Out:
# 231

# %% [markdown]
# ## **dropping unused columns**

# %%
data_merged.drop(columns=['Prospect ID', 'Phone Number', 'Email'], inplace=True)
data_merged.head()
# Out:
#   Mobile Number           Primary Source Campaign          Lead Stage  \
# 0    6290470684   The_mini_trader_YT1_2_July_2024       L2-in process
# 1    7750035479       Bull_Earner_YT1_2_July_2024       L2-in process
# 2    9012564044  Snehilop_Gaming_YT1_15_June_2024  999-Account Opened
# 3    7797203221   The_mini_trader_YT1_2_July_2024       L2-in process
# 4    9777667419       Bull_Earner_YT1_2_July_2024       L2-in process
#
#           eKYC Stage Code  Total Payment Amount              Created On  \
# 0                e2_Email                   0.0  2024-07-04 09:41:48 AM
# 1        e6_Onscreen_Sign                   0.0  2024-07-04 09:39:44 AM
# 2  e14_Activation_Process                1207.0  2024-07-04 09:22:23 AM
# 3               e1_Mobile                   0.0  2024-07-03 08:49:18 PM
# 4               e1_Mobile                   0.0  2024-07-04 09:37:57 AM
#
#                Bitly Link agency
# 0  https://bit.ly/4coDGcx     BS
# 1  https://bit.ly/4cGy3py     BS
# 2  https://bit.ly/3XpzUuy     BS
# 3  https://bit.ly/4coDGcx     BS
# 4  https://bit.ly/4cGy3py     BS

# %% [markdown]
# ## **creating a pivot**

# %%
data_merged.columns = data_merged.columns.astype(str)
data_merged['Total Payment Amount'] = data_merged['Total Payment Amount'].astype('int64')
data_merged.dtypes
# Out:
# Mobile Number              object
# Primary Source Campaign    object
# Lead Stage                 object
# eKYC Stage Code            object
# Total Payment Amount        int64
# Created On                 object
# Bitly Link                 object
# agency                     object
# dtype: object

# %%
data_merged = data_merged.reset_index(drop=True)

# %%
data_merged_pivot = pd.pivot_table(data_merged, 
                                   index='Primary Source Campaign',
                                   columns='Lead Stage',
                                   values='Mobile Number',
                                   aggfunc='count',
                                   fill_value=0)
data_merged_pivot
# Out:
# Lead Stage                                999-Account Opened  L2-in process  \
# Primary Source Campaign
# 7_Dreams_India_Official_YT1_18_June_2024                  27             21
# Alok_Games_YT1_14_June_2024                                0              0
# Bull_Earner_YT1_2_July_2024                                0              3
# Charging_Point_Hindi_YT1_18_June_2024                      2              0
# Chaudhary_Tips_YT1_10_June_2024                            0              1
# Market_Support_YT1_11_June_2024                           13              1
# Market_Support_YT1_3_June_2024                             0              0
# Mission_Market_YT1_14_June_2024                            2              0
# Mr._Rishi_YT1_27_May_2024                                  1              0
# My_stock_World_YT1_18_June_2024                           18              5
# Ready_To_Invest_YT1_7_June_2024                            4              0
# Rs_Fintech_YT1_13_June_2024                                0              4
# Rs_Fintech_YT1_6_June_2024                                 1              0
# Share_Market_Analysis_YT1_1_July_2024                      0              1
# Shrija_Saha_YT1_13_June_2024                               2              0
# Snehilop_Gaming_YT1_15_June_2024                          30              3
# The_mini_trader_YT1_12_June_2024                           2              2
# The_mini_trader_YT1_2_July_2024                            0             21
# Vivek_Singh_Rana_YT1_1_June_2024                           0              2
# aayush_SSM_YT1_6_June_2024                                 0              1
#
# Lead Stage                                L4-Account Opened
# Primary Source Campaign
# 7_Dreams_India_Official_YT1_18_June_2024                  2
# Alok_Games_YT1_14_June_2024                               1
# Bull_Earner_YT1_2_July_2024                               6
# Charging_Point_Hindi_YT1_18_June_2024                     0
# Chaudhary_Tips_YT1_10_June_2024                           0
# Market_Support_YT1_11_June_2024                           1
# Market_Support_YT1_3_June_2024                            1
# Mission_Market_YT1_14_June_2024                           0
# Mr._Rishi_YT1_27_May_2024                                 0
# My_stock_World_YT1_18_June_2024                          12
# Ready_To_Invest_YT1_7_June_2024                           0
# Rs_Fintech_YT1_13_June_2024                               2
# Rs_Fintech_YT1_6_June_2024                                0
# Share_Market_Analysis_YT1_1_July_2024                    10
# Shrija_Saha_YT1_13_June_2024                              0
# Snehilop_Gaming_YT1_15_June_2024                          2
# The_mini_trader_YT1_12_June_2024                          0
# The_mini_trader_YT1_2_July_2024                          27
# Vivek_Singh_Rana_YT1_1_June_2024                          0
# aayush_SSM_YT1_6_June_2024                                0

# %%
print(data_merged_pivot.shape[0])
print(data_merged['Primary Source Campaign'].nunique())
# Out:
# 20
# 20

# %%
sum_row = data_merged_pivot.sum()
sum_row.name = 'Total'
data_merged_pivot = pd.concat([data_merged_pivot, pd.DataFrame(sum_row).T])

# %%
data_merged_pivot = data_merged_pivot.reset_index()
data_merged_pivot.tail()
# Out:
# Lead Stage                             index  999-Account Opened  \
# 16          The_mini_trader_YT1_12_June_2024                   2
# 17           The_mini_trader_YT1_2_July_2024                   0
# 18          Vivek_Singh_Rana_YT1_1_June_2024                   0
# 19                aayush_SSM_YT1_6_June_2024                   0
# 20                                     Total                 102
#
# Lead Stage  L2-in process  L4-Account Opened
# 16                      2                  0
# 17                     21                 27
# 18                      2                  0
# 19                      1                  0
# 20                     65                 64

# %%
# Rename the columns as needed
data_merged_pivot.columns.name = None
data_merged_pivot.columns = ['Primary Source Campaign', '999-Account Opened', 'L2-in process', 'L4-Account Opened']
data_merged_pivot.head()
# Out:
#                     Primary Source Campaign  999-Account Opened  \
# 0  7_Dreams_India_Official_YT1_18_June_2024                  27
# 1               Alok_Games_YT1_14_June_2024                   0
# 2               Bull_Earner_YT1_2_July_2024                   0
# 3     Charging_Point_Hindi_YT1_18_June_2024                   2
# 4           Chaudhary_Tips_YT1_10_June_2024                   0
#
#    L2-in process  L4-Account Opened
# 0             21                  2
# 1              0                  1
# 2              3                  6
# 3              0                  0
# 4              1                  0

# %% [markdown]
# ## **merging the Bitly Link	with Pivot**

# %%
# Create a dictionary to map 'Primary Source Campaign' to 'Bitly Link'
campaign_to_bitly = data_merged.set_index('Primary Source Campaign')['Bitly Link'].to_dict()

# %%
# Add 'Bitly Link' column to data_merged_pivot by mapping
data_merged_pivot['Bitly Link'] = data_merged_pivot['Primary Source Campaign'].map(campaign_to_bitly)

# %%
data_merged_pivot.shape[0]
# Out:
# 21

# %%
data_merged_pivot
# Out:
#                      Primary Source Campaign  999-Account Opened  \
# 0   7_Dreams_India_Official_YT1_18_June_2024                  27
# 1                Alok_Games_YT1_14_June_2024                   0
# 2                Bull_Earner_YT1_2_July_2024                   0
# 3      Charging_Point_Hindi_YT1_18_June_2024                   2
# 4            Chaudhary_Tips_YT1_10_June_2024                   0
# 5            Market_Support_YT1_11_June_2024                  13
# 6             Market_Support_YT1_3_June_2024                   0
# 7            Mission_Market_YT1_14_June_2024                   2
# 8                  Mr._Rishi_YT1_27_May_2024                   1
# 9            My_stock_World_YT1_18_June_2024                  18
# 10           Ready_To_Invest_YT1_7_June_2024                   4
# 11               Rs_Fintech_YT1_13_June_2024                   0
# 12                Rs_Fintech_YT1_6_June_2024                   1
# 13     Share_Market_Analysis_YT1_1_July_2024                   0
# 14              Shrija_Saha_YT1_13_June_2024                   2
# 15          Snehilop_Gaming_YT1_15_June_2024                  30
# 16          The_mini_trader_YT1_12_June_2024                   2
# 17           The_mini_trader_YT1_2_July_2024                   0
# 18          Vivek_Singh_Rana_YT1_1_June_2024                   0
# 19                aayush_SSM_YT1_6_June_2024                   0
# 20                                     Total                 102
#
#     L2-in process  L4-Account Opened              Bitly Link
# 0              21                  2  https://bit.ly/4b71j7P
# 1               0                  1  https://bit.ly/4bYYYwR
# 2               3                  6  https://bit.ly/4cGy3py
# 3               0                  0  https://bit.ly/3z8evw1
# 4               1                  0  https://bit.ly/3x3kyRY
# 5               1                  1  https://bit.ly/3RpGdur
# 6               0                  1  https://bit.ly/3RcX57L
# 7               0                  0  https://bit.ly/3z36rMY
# 8               0                  0  https://bit.ly/4dV1G8d
# 9               5                 12  https://bit.ly/3zgzzjM
# 10              0                  0  https://bit.ly/3yQVG0i
# 11              4                  2  https://bit.ly/3VrgCSW
# 12              0                  0  https://bit.ly/4b09NxK
# 13              1                 10  https://bit.ly/3zu0JnB
# 14              0                  0  https://bit.ly/3VHEuTV
# 15              3                  2  https://bit.ly/3XpzUuy
# 16              2                  0  https://bit.ly/4bXYrLE
# 17             21                 27  https://bit.ly/4coDGcx
# 18              2                  0  https://bit.ly/3wRxVEK
# 19              1                  0  https://bit.ly/4cbb0mA
# 20             65                 64                     NaN

# %% [markdown]
# ## **Coverting all results to EXCEL File**

# %%
with pd.ExcelWriter('excel files//output.xlsx', engine='xlsxwriter') as writer:
    data_merged.to_excel(writer ,sheet_name='Data Cleaned', index=False)
    data_merged_pivot.to_excel(writer, sheet_name='Pivot', index=False)
